# %%
import sys
sys.path.append('../src/')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
#from DGMCA import DGMCA as dgmca
#from DGMCA_omp import *
#from GMCA import Core_GMCA as gmca
import copy as cp
from tqdm import tqdm
import time
import scipy.io as sio
#import DGMCA_omp_v3 as dgo
#import DGMCA as dg
import GMCA as gmca

# %%
data = sio.loadmat("CaHist_FM_rho0_1_cond1_Nov30_FixedNbBatches_2019.mat")

Oca1000 = data["Oca1000"]
Oca100 = data["Oca100"]
Oca25 = data["Oca25"]
Oca10 = data["Oca10"]

rOca1000 = data["rOca1000"]
rOca100 = data["rOca100"]
rOca25 = data["rOca25"]
rOca10 = data["rOca10"]

Ocam1000 = data["Ocam1000"][0]
Ocam100 = data["Ocam100"][0]
Ocam25 = data["Ocam25"][0]
Ocam10 = data["Ocam10"][0]

rOcam1000 = data["rOcam1000"][0]
rOcam100 = data["rOcam100"][0]
rOcam25 = data["rOcam25"][0]
rOcam10 = data["rOcam10"][0]

# %%
save = True

fsize = 18
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

niter = -1
bins = np.linspace(-4, -0.5, 40)
#plt.hist(np.log10(rOca10[niter]),bins,alpha=0.3,density=True,color=vcol[3],label="B = 10")
plt.hist(np.log10(rOca25[niter]),bins,alpha=0.3,density=False,color=vcol[2],label="B = 25")
#lt.hist(np.log10(rOca100[niter]),bins,alpha=0.3,density=True,color=vcol[0],label="B = 100")
plt.hist(np.log10(rOca1000[niter]),bins,alpha=0.3,density=False,color=vcol[1],label="B = 1000")
#plt.hist(np.log10(rOca10000[niter]),bins,alpha=0.3,density=False,color=vcol[4],label="B = 10000")
#plt.hist(np.log10(Ocam10[98]),bins,alpha=0.3,density=True)
#plt.axvline(x=np.log10(rOcam10[niter]),color=vcol[3],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(rOcam25[niter]),color=vcol[2],lw=8,alpha=0.75,linestyle=':')
#plt.axvline(x=np.log10(rOcam25[niter]),color=vcol[3],lw=8,alpha=0.75,linestyle=':')
#plt.axvline(x=np.log10(rOcam100[niter]),color=vcol[0],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(rOcam1000[niter]),color=vcol[1],lw=8,alpha=0.75,linestyle=':')
#plt.axvline(x=np.log10(rOcam10000[niter]),color=vcol[4],lw=8,alpha=0.75,linestyle=':')
plt.xlabel("CA",fontsize = fsize+2,weight='bold')
plt.ylabel("Histogram",fontsize = fsize+2,weight='bold')
plt.legend()
plt.ylim(0,200)
fig = plt.gcf()
fig.set_size_inches(10, 7)
if save:
    fig.savefig('CaHist_rFM_rho0_1.png', dpi=600, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)
# Out:
# /Users/jbobin/Documents/ThirdParty/Python-3.7.5/BUILD/lib/python3.7/site-packages/ipykernel_launcher.py:32: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
save = True

fsize = 18
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

niter = -1
bins = np.linspace(-4, -0.5, 40)
#plt.hist(np.log10(rOca10[niter]),bins,alpha=0.3,density=True,color=vcol[3],label="B = 10")
plt.hist(np.log10(Oca25[niter]),bins,alpha=0.3,density=False,color=vcol[2],label="B = 25")
#lt.hist(np.log10(rOca100[niter]),bins,alpha=0.3,density=True,color=vcol[0],label="B = 100")
plt.hist(np.log10(Oca1000[niter]),bins,alpha=0.3,density=False,color=vcol[1],label="B = 1000")
#plt.hist(np.log10(rOca10000[niter]),bins,alpha=0.3,density=False,color=vcol[4],label="B = 10000")
#plt.hist(np.log10(Ocam10[98]),bins,alpha=0.3,density=True)
#plt.axvline(x=np.log10(rOcam10[niter]),color=vcol[3],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(Ocam25[niter]),color=vcol[2],lw=8,alpha=0.75,linestyle=':')
#plt.axvline(x=np.log10(rOcam25[niter]),color=vcol[3],lw=8,alpha=0.75,linestyle=':')
#plt.axvline(x=np.log10(rOcam100[niter]),color=vcol[0],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(Ocam1000[niter]),color=vcol[1],lw=8,alpha=0.75,linestyle=':')
#plt.axvline(x=np.log10(rOcam10000[niter]),color=vcol[4],lw=8,alpha=0.75,linestyle=':')
plt.xlabel("CA",fontsize = fsize+2,weight='bold')
plt.ylabel("Histogram",fontsize = fsize+2,weight='bold')
plt.legend()
plt.ylim(0,200)
plt.xlim(-3.5,0)

fig = plt.gcf()
fig.set_size_inches(10, 7)
if save:
    fig.savefig('CaHist_FM_rho0_1.png', dpi=600, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

plt.loglog(rOcam1000[5:998],lw=8,color=vcol[3],label="B=1000")
plt.loglog(rOcam100[5:998],lw=8,color=vcol[2],label="B=100")
plt.loglog(rOcam25[5:998],lw=8,color=vcol[1],label="B=25")
plt.loglog(rOcam10[5:998],lw=8,color=vcol[0],label="B=10")

plt.loglog(rOca1000[5:998],alpha=0.1,color=vcol[3])
plt.loglog(rOca100[5:998],alpha=0.01,color=vcol[2])
plt.loglog(rOca25[5:998],alpha=0.01,color=vcol[1])
plt.loglog(rOca10[5:998],alpha=0.01,color=vcol[0])

plt.xlabel("Iteration #",fontsize = fsize+2,weight='bold')
plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')

plt.legend()
fig = plt.gcf()
fig.set_size_inches(15, 10)
if save:
    fig.savefig('CaEvolution_rFM_rho0_1_cond3_June17.png', dpi=300, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# /Users/jbobin/Documents/ThirdParty/Python-3.7.4_BUILD/lib/python3.7/site-packages/IPython/core/events.py:88: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   func(*args, **kwargs)
# /Users/jbobin/Documents/ThirdParty/Python-3.7.4_BUILD/lib/python3.7/site-packages/IPython/core/pylabtools.py:128: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)

#plt.loglog(rOcam1000[5:998],lw=8,color=vcol[3],label="B=1000")
#plt.loglog(rOcam100[5:998],lw=8,color=vcol[2],label="B=100")
plt.loglog(rOcam25[5:998],lw=8,color=vcol[1],label="B=25")
#plt.loglog(rOcam10[5:998],lw=8,color=vcol[0],label="B=10")

#plt.loglog(rOca1000[5:998],alpha=0.1,color=vcol[3])
#plt.loglog(rOca100[5:998],alpha=0.01,color=vcol[2])
#plt.loglog(rOca25[5:998],alpha=0.01,color=vcol[1])
#plt.loglog(rOca10[5:998],alpha=0.01,color=vcol[0])

plt.xlabel("Iteration #",fontsize = fsize+2,weight='bold')
plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')

#plt.legend()
fig = plt.gcf()
fig.set_size_inches(10, 7)
fig.savefig('CaEvolution_rFM_rho0_1_cond3_CONVERGENCE.png', dpi=600, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)
# Out:
# /Users/jbobin/Documents/ThirdParty/Python-3.7.5/BUILD/lib/python3.7/site-packages/ipykernel_launcher.py:26: MatplotlibDeprecationWarning:
# The frameon kwarg was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use facecolor instead.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

plt.loglog(rOcam1000[5:998],lw=8,color=vcol[1])
plt.loglog(rOcam100[5:998],lw=8,color=vcol[0])
plt.loglog(rOcam10[5:998],lw=8,color=vcol[2])
plt.loglog(rOca1000[5:998],alpha=0.05,color=vcol[1])
plt.loglog(rOca25[5:998],alpha=0.1,color=vcol[0])
plt.loglog(rOca10[5:998],alpha=0.01,color=vcol[2])

plt.xlabel("Iteration #",fontsize = fsize+2,weight='bold')
plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')

plt.legend(['1000','100','10'])
fig = plt.gcf()
fig.set_size_inches(15, 10)
if save:
    fig.savefig('CaEvolution_rFM_rho0_1_cond3_June17.png', dpi=300, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)
