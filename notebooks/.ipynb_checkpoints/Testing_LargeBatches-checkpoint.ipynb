# %%
import sys
sys.path.append('../src/')
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
from DGMCA import DGMCA as dgmca
from DGMCA_omp import *
from GMCA import Core_GMCA as gmca
import copy as cp
from tqdm import tqdm
import time
import scipy.io as sio
import DGMCA_omp as dgo
import DGMCA as dg
import GMCA as gmca

# %%
totalSize = 10000
n_s = 5 # Number of sources
n_obs = 20 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
BlockSize =  n_s
nmax = 250
kend = 1.

# We should do MC

X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=3,alpha=rho)

R = np.dot(X,X.T)
D,V = lng.eig(R)
Ainit = V[:,0:n_s]
Ainit = np.random.rand(n_obs,n_s)

Agmca = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=1,verb=0,Init=0,SCOpt=0,Kmax=1)["mixmat"]

# %%
totalSize = 10000
nmax=250

BS = 10
out_omp10,FMw10,th10,Oca10,Osad10,Ocam10,Osadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS=100
out_omp100,FMw100,th100,Oca100,Osad100,Ocam100,Osadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS = 1000
out_omp1000,FMw1000,th1000,Oca1000,Osad1000,Ocam1000,Osadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)


BS = 10
out_omp10_FR,FMw10_FR,th10_FR,Oca10_FR,Osad10_FR,Ocam10_FR,Osadm10_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS=100
out_omp100_FR,FMw100_FR,th100_FR,Oca100_FR,Osad100_FR,Ocam100_FR,Osadm100_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS = 1000
out_omp1000_FR,FMw1000_FR,th1000_FR,Oca1000_FR,Osad1000_FR,Ocam1000_FR,Osadm1000_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)

# %%
plt.semilogy(Oca10,'b',alpha=0.01)
plt.semilogy(Ocam10,'b',lw=4)

plt.semilogy(Oca100,'g',alpha=0.1)
plt.semilogy(Ocam100,'g',lw=4)

plt.semilogy(Oca1000,'y',alpha=0.4)
plt.semilogy(Ocam1000,'y',lw=4)

print(EvalCriterion_eval(A0,S0,Agmca,S0)['ca_mean'])
# Out:
# 0.00018506017466331015

# %%
plt.semilogy(Oca10_FR,'b',alpha=0.01)
plt.semilogy(Ocam10_FR,'b',lw=4)

plt.semilogy(Oca100_FR,'g',alpha=0.1)
plt.semilogy(Ocam100_FR,'g',lw=4)

plt.semilogy(Oca1000_FR,'y',alpha=0.4)
plt.semilogy(Ocam1000_FR,'y',lw=4)

# %%
R = np.dot(X,X.T)
D,V = lng.eig(R)
Ainit = V[:,0:n_s]

totalSize = 10000
nmax=250

BS = 10
out_omp10,FMw10,th10,Oca10,Osad10,Ocam10,Osadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS=100
out_omp100,FMw100,th100,Oca100,Osad100,Ocam100,Osadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS = 1000
out_omp1000,FMw1000,th1000,Oca1000,Osad1000,Ocam1000,Osadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)


BS = 10
out_omp10_FR,FMw10_FR,th10_FR,Oca10_FR,Osad10_FR,Ocam10_FR,Osadm10_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS=100
out_omp100_FR,FMw100_FR,th100_FR,Oca100_FR,Osad100_FR,Ocam100_FR,Osadm100_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS = 1000
out_omp1000_FR,FMw1000_FR,th1000_FR,Oca1000_FR,Osad1000_FR,Ocam1000_FR,Osadm1000_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)

# %%
plt.semilogy(Oca10,'b',alpha=0.01)
plt.semilogy(Ocam10,'b',lw=4)

plt.semilogy(Oca100,'g',alpha=0.1)
plt.semilogy(Ocam100,'g',lw=4)

plt.semilogy(Oca1000,'y',alpha=0.4)
plt.semilogy(Ocam1000,'y',lw=4)

print(EvalCriterion_eval(A0,S0,Agmca,S0)['ca_mean'])
# Out:
# 0.00018506017466331015

# %%
plt.semilogy(Oca10_FR,'b',alpha=0.01)
plt.semilogy(Ocam10_FR,'b',lw=4)

plt.semilogy(Oca100_FR,'g',alpha=0.1)
plt.semilogy(Ocam100_FR,'g',lw=4)

plt.semilogy(Oca1000_FR,'y',alpha=0.4)
plt.semilogy(Ocam1000_FR,'y',lw=4)

# %%
R = np.dot(X,X.T)
D,V = lng.eig(R)
Ainit = np.copy(A0)

totalSize = 10000
nmax=250

BS = 10
out_omp10,FMw10,th10,Oca10,Osad10,Ocam10,Osadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS=100
out_omp100,FMw100,th100,Oca100,Osad100,Ocam100,Osadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS = 1000
out_omp1000,FMw1000,th1000,Oca1000,Osad1000,Ocam1000,Osadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)


BS = 10
out_omp10_FR,FMw10_FR,th10_FR,Oca10_FR,Osad10_FR,Ocam10_FR,Osadm10_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS=100
out_omp100_FR,FMw100_FR,th100_FR,Oca100_FR,Osad100_FR,Ocam100_FR,Osadm100_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
BS = 1000
out_omp1000_FR,FMw1000_FR,th1000_FR,Oca1000_FR,Osad1000_FR,Ocam1000_FR,Osadm1000_FR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)
# Out:
# ../src/utils_dgmca.py:416: RuntimeWarning: invalid value encountered in arccos
#   Q = abs(np.arccos(np.sum(gA0*gA,axis=0))*180./np.pi)

# %%
#plt.semilogy(Oca10,'b',alpha=0.01)
plt.semilogy(Ocam10,'b',lw=4)

#plt.semilogy(Oca100,'g',alpha=0.1)
plt.semilogy(Ocam100,'g',lw=4)

#plt.semilogy(Oca1000,'y',alpha=0.4)
plt.semilogy(Ocam1000,'y',lw=4)

print(EvalCriterion_eval(A0,S0,Agmca,S0)['ca_mean'])
# Out:
# 0.00018506017466331015

# %%
#plt.semilogy(Oca10_FR,'b',alpha=0.01)
plt.semilogy(Ocam10_FR,'b',lw=4)

#plt.semilogy(Oca100_FR,'g',alpha=0.1)
plt.semilogy(Ocam100_FR,'g',lw=4)

#plt.semilogy(Oca1000_FR,'y',alpha=0.4)
plt.semilogy(Ocam1000_FR,'y',lw=4)

# %%
totalSize = 10000
BS = 10
out_omp1000,FMw1000,th1000,Oca1000,Osad1000,Ocam1000,Osadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=250,BlockSize = 5,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)

# %%
plt.semilogy(Oca1000,'b',alpha=0.1)
plt.semilogy(Ocam1000,lw=4)

# %%
totalSize = 10000
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=3,alpha=rho)

BS = 10
out_omp1000_2NoFR,FMw1000_2NoFR,th1000_2NoFR,Oca1000_2NoFR,Osad1000_2NoFR,Ocam1000_2NoFR,Osadm1000_2NoFR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=250,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)

BS = 10
out_omp1000,FMw1000_2NoFR,th1000_2NoFR,Oca1000_2NoFR,Osad1000_2NoFR,Ocam1000_2NoFR,Osadm1000_2NoFR = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=250,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)

# BS = 1000
# out_omp1000_2,FMw1000_2,th1000_2,Oca1000_2,Osad1000_2,Ocam1000_2,Osadm1000_2 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=1,q_f=0.1,AggMeth='rFM',Equal=False,nmax=50,BlockSize = None,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, A0=A0)

# %%
plt.loglog(Oca1000_2NoFR,'b',alpha=0.1)
plt.loglog(Ocam1000_2NoFR,lw=4)
plt.loglog(Oca1000,'g',alpha=0.1)
plt.loglog(Ocam1000,'g',lw=4)

# %%
print(rho)
# Out:
# 0.1
