# %%
import sys
sys.path.append("../src/")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
import copy as cp
#from tqdm import tqdm
import DGMCA_omp as dgo
import time
import scipy.io as sio
from sklearn.decomposition import MiniBatchDictionaryLearning
import GMCA as gmca
import os
WrapLoc = os.environ['PYWRAP3_LOC']
sys.path.insert(1,WrapLoc)
import pyStarlet as ps
## Create partial correlations or use spectro gamma data ?

# %% [markdown]
# ## Make some data

# %%
# Spectro gamma

J = 4

data = sio.loadmat("/data_diskb/Python/LENA_DEVL/Toolbox/BSS/SpectroGamma/Simus/SpectroGamma_Simus.mat")
A0 = data["A"]
S0 = data["S"]
Name = data["Name"]

S0 = np.diag(1./np.linalg.norm(S0,axis=1))@S0
A0 = A0@np.diag(1./np.linalg.norm(A0,axis=0))

X0 = A0@S0

Xw = ps.forward1d(X0,J=J)[:,:,0:J]
Xw = Xw.reshape(Xw.shape[0],-1)
plt.plot(Xw[10])
print(np.shape(Xw))
# Out:
# (20, 64960)

# %%
import scipy.io as sio

FR = False

critA_omp = []
critA = []
Time_omp = []
Time = []

vBS = np.array([5,7,10,15,25,50,100,250,500,1000,2500])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        

Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 10
nmax = 250
SNR = 80.

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):
    
    Ainit = np.random.randn(n_obs,n_s)
    Ainit = Ainit/np.linalg.norm(Ainit,axis=0)

    N = np.random.randn(Xw.shape[0],Xw.shape[1])
    X = Xw + N/np.linalg.norm(N)*np.linalg.norm(Xw)*np.power(10.,-SNR/20.)
    
    for r in range(len(vBS)):

        BS = vBS[r]
    
        print("BS = ",BS)
    
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=2,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        print("GMCA : ",critA[-1])
        
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])

        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        print("rFM : ",critA_rFM[-1])

        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        print("rFM FR: ",critA_rFMeq[-1])

        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        print("ODL : ",critA_ODL[-1])
        
        sio.savemat("DGMCA_BatchSize_SpectroGamma_SNR80.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# BS =  5
# GMCA :  0.13579937721380136
# rFM :  0.001295592339468494
# rFM FR:  0.0019153615861220038
# ODL :  0.5502110073069855
# BS =  7
# GMCA :  0.13579937721380136
# rFM :  0.010994045820126544
# rFM FR:  0.0013214355911306114
# ODL :  0.529593006087207
# BS =  10
# GMCA :  0.13579937721380136
# rFM :  0.0009921050886184857
# rFM FR:  0.0008789741841544102
# ODL :  0.722522148100272
# BS =  15
# GMCA :  0.13579937721380136
# rFM :  0.0010608050081668495
# rFM FR:  0.0010402698173362813
# ODL :  1.0105897535979314
# BS =  25
# GMCA :  0.13579937721380136
# rFM :  0.0009415990897644895
# rFM FR:  0.0006614885940325145
# ODL :  0.41157781205408617
# BS =  50
# GMCA :  0.13579937721380136
# rFM :  0.004015940142625536
# rFM FR:  0.001046565827147949
# ODL :  0.5685944807368396
# BS =  100
# GMCA :  0.13579937721380136
# rFM :  0.10461777460191675
# rFM FR:  0.004375494883207999
# ODL :  0.7472232024258423
# BS =  250
# GMCA :  0.13579937721380136
# rFM :  0.31521946055873434
# rFM FR:  0.03795504947089693
# ODL :  0.8008120925226029
# BS =  500
# GMCA :  0.13579937721380136
# rFM :  0.5334507862414644
# rFM FR:  0.2552563784764169
# ODL :  0.5780390571954402
# BS =  1000
# GMCA :  0.13579937721380136
# rFM :  0.5905537973385724
# rFM FR:  0.5844571459682499
# ODL :  0.4106175988991799
# BS =  2500
# GMCA :  0.13579937721380136
# rFM :  0.48557544236980366
# rFM FR:  0.5718686274902854
# ODL :  0.7259089212524911
# BS =  5
# GMCA :  0.13580014445102534
# rFM :  0.000923123825618657
# rFM FR:  0.0010308880871856456
# ODL :  0.759693693264777
# BS =  7
# GMCA :  0.13580014445102534
# rFM :  0.0010544943478730633
# rFM FR:  0.0008281990685743571
# ODL :  0.37793702044236477
# BS =  10
# GMCA :  0.13580014445102534
# rFM :  0.0007207749894547483
# rFM FR:  0.0008075615555277755
# ODL :  0.5271296792825714
# BS =  15
# GMCA :  0.13580014445102534
# rFM :  0.001000777214410594
# rFM FR:  0.001042357888833685
# ODL :  0.7416085006967974
# BS =  25
# GMCA :  0.13580014445102534
# rFM :  0.0006835473581951373
# rFM FR:  0.000681811640107424
# ODL :  0.4066769601961169
# BS =  50
# GMCA :  0.13580014445102534
# rFM :  0.002752726664089418
# rFM FR:  0.0009247929700500965
# ODL :  0.47607355311561667
# BS =  100
# GMCA :  0.13580014445102534
# rFM :  0.11890617251834032
# rFM FR:  0.006654056506328473
# ODL :  0.6236113195076867
# BS =  250
# GMCA :  0.13580014445102534
# rFM :  0.26460087039734326
# rFM FR:  0.02395039378424813
# ODL :  0.5107481143659867
# BS =  500
# GMCA :  0.13580014445102534
# rFM :  0.6178062678830818
# rFM FR:  0.4347553229873159
# ODL :  0.4374347005501285
# BS =  1000
# GMCA :  0.13580014445102534
# rFM :  0.6866931854549277
# rFM FR:  0.6490373304771492
# ODL :  0.39651485756945626
# BS =  2500
# GMCA :  0.13580014445102534
# rFM :  0.7156163938780835
# rFM FR:  0.7112793441077006
# ODL :  0.2839284921711377
# BS =  5
# GMCA :  0.13580031868302336
# rFM :  0.0017902629325807675
# rFM FR:  0.0017728640554753629
# ODL :  0.7703523414144049
# BS =  7
# GMCA :  0.13580031868302336
# rFM :  0.001081140328634208
# rFM FR:  0.0012270375182914322
# ODL :  0.8486392556874396
# BS =  10
# GMCA :  0.13580031868302336
# rFM :  0.0007444892942293927
# rFM FR:  0.000796851084707324
# ODL :  0.4949571933987281
# BS =  15
# GMCA :  0.13580031868302336
# rFM :  0.0009558159128535083
# rFM FR:  0.0007446810964402347
# ODL :  0.41104076467766415
# BS =  25
# GMCA :  0.13580031868302336
# rFM :  0.001044355958736086

# %%
import scipy.io as sio

FR = False

critA_omp = []
critA = []
Time_omp = []
Time = []

vBS = np.array([5,7,10,15,25,50,100,250,500,1000,2500])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        

Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 10
nmax = 250
SNR = 40.

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):
    
    Ainit = np.random.randn(n_obs,n_s)
    Ainit = Ainit/np.linalg.norm(Ainit,axis=0)

    N = np.random.randn(Xw.shape[0],Xw.shape[1])
    X = Xw + N/np.linalg.norm(N)*np.linalg.norm(Xw)*np.power(10.,-SNR/20.)
    
    for r in range(len(vBS)):

        BS = vBS[r]
    
        print("BS = ",BS)
    
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=2,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        print("GMCA : ",critA[-1])
        
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])

        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        print("rFM : ",critA_rFM[-1])

        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        print("rFM FR: ",critA_rFMeq[-1])

        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        print("ODL : ",critA_ODL[-1])
        
        sio.savemat("DGMCA_BatchSize_SpectroGamma_SNR40.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})

# %%
import scipy.io as sio

FR = False

critA_omp = []
critA = []
Time_omp = []
Time = []

vBS = np.array([5,7,10,15,25,50,100,250,500,1000,2500])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        

Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 10
nmax = 250
SNR = 60.

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):
    
    Ainit = np.random.randn(n_obs,n_s)
    Ainit = Ainit/np.linalg.norm(Ainit,axis=0)

    N = np.random.randn(Xw.shape[0],Xw.shape[1])
    X = Xw + N/np.linalg.norm(N)*np.linalg.norm(Xw)*np.power(10.,-SNR/20.)
    
    for r in range(len(vBS)):

        BS = vBS[r]
    
        print("BS = ",BS)
    
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=2,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        print("GMCA : ",critA[-1])
        
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])

        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=False,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        print("rFM : ",critA_rFM[-1])

        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        print("rFM FR: ",critA_rFMeq[-1])

        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        print("ODL : ",critA_ODL[-1])
        
        sio.savemat("DGMCA_BatchSize_SpectroGamma_SNR60.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
