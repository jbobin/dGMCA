# %% [markdown]
# # DGMCA experiments
# ### Role played by the threshold

# %%
import sys
sys.path.append("../src/")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
import copy as cp
#from tqdm import tqdm
import DGMCA_omp as dgo
import time
import scipy.io as sio

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([7,10,15,25,50,100,250,500,1000,2500])
n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.05
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 2

N_MC = 5
BS = totalSize
nmax = 500

critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []

for nmc in range(N_MC):

    X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
    
    t2 = time.time()
    out,FMw,th = dgo.Core_DGMCA(X=X,n=5,A=Ainit,kend=kend,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=totalSize, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
    t3 = time.time()
    Time.append(t3-t2)
    critA.append(EvalCriterion_eval(A0,S0,out,S0)['ca_mean'])
    
    print(nmc,BS)
    
    for r in range(len(vBS)):

        BS = vBS[r]
        
        print(nmc,BS)
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUCeq.append(t2-t1)
        critA_EUCeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUC.append(t2-t1)
        critA_EUC.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        sio.savemat("DGMCA_KEND_2_April30.mat",mdict={"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# Total size :  10000  - Number of blocks:  1
# 0 10000
# 0 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 0 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 0 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 0 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 0 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 0 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 0 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 0 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 0 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 0 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 1 2500
# 1 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 1 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 1 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 1 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 1 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 1 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 1 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 1 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 1 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 1 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 2 2500
# 2 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 2 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 2 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 2 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 2 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 2 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 2 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 2 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 2 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 2 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 3 2500
# 3 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 3 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 3 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 3 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 3 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 3 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 3 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 3 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 3 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 3 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 4 2500
# 4 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 4 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 4 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 4 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 4 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 4 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 4 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 4 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 4 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 4 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4

# %%
### Plotting the results

N_MC = 5
vBS = np.array([7,10,15,25,50,100,250,500,1000,2500])
nval = len(vBS)
ntot = N_MC*nval
totalSize = 10000

data = sio.loadmat("DGMCA_KEND_2_April30.mat")

Time_FMeq = data["Time_FMeq"]
Time_FM = data["Time_FM"]
Time_rFMeq = data["Time_rFMeq"]
Time_rFM = data["Time_rFM"]
Time_EUCeq = data["Time_EUCeq"]
Time_EUC = data["Time_EUC"]
critA_FMeq = data["critA_FMeq"]
critA_FM = data["critA_FM"]
critA_rFMeq = data["critA_rFMeq"]
critA_rFM = data["critA_rFM"]
critA_EUCeq = data["critA_EUCeq"]
critA_EUC = data["critA_EUC"]
Time = data["Time"]
critA = data["critA"]

CompTime = np.mean(Time)
Crit = np.mean(critA)
DCompTime_FMeq = np.mean(np.reshape(Time_FMeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_FMeq = np.mean(np.reshape(critA_FMeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_FM = np.mean(np.reshape(Time_FM[0:ntot],(N_MC,-1)),axis=0)
DCrit_FM = np.mean(np.reshape(critA_FM[0:ntot],(N_MC,-1)),axis=0)
DCompTime_EUCeq = np.mean(np.reshape(Time_EUCeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_EUCeq = np.mean(np.reshape(critA_EUCeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_EUC = np.mean(np.reshape(Time_EUC[0:ntot],(N_MC,-1)),axis=0)
DCrit_EUC = np.mean(np.reshape(critA_EUC[0:ntot],(N_MC,-1)),axis=0)
DCompTime_rFMeq = np.mean(np.reshape(Time_rFMeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_rFMeq = np.mean(np.reshape(critA_rFMeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_rFM = np.mean(np.reshape(Time_rFM[0:ntot],(N_MC,-1)),axis=0)
DCrit_rFM = np.mean(np.reshape(critA_rFM[0:ntot],(N_MC,-1)),axis=0)

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

plt.loglog(vBS,DCrit_FMeq,'--s',alpha=0.7,lw=4,markersize=10,color=vcol[0])
#plt.semilogy(vBS,DCrit_FM)
plt.loglog(vBS,DCrit_rFMeq,'d--',lw=4,alpha=0.7,markersize=10,color=vcol[1])
#plt.semilogy(vBS,DCrit_rFM,'d')
plt.loglog(vBS,DCrit_EUCeq,'o--',lw=4,alpha=0.7,markersize=10,color=vcol[2])
#plt.semilogy(vBS,DCrit_EUC,'o')
plt.loglog(vBS,Crit*np.ones_like(DCrit_FMeq),'--p',alpha=0.7,lw=4,markersize=10,color=vcol[3])

plt.legend(["FMeq","rFMeq","EUCeq","NoBatch"])

plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')
plt.xlabel("Batch size",fontsize = fsize+2,weight='bold')
plt.title('Threshold k = 2 - #samples = 10000',fontsize = fsize+2,weight='bold')
plt.savefig('NoWeighting_K2_nsamples10000_Cd1_ns5_nobs20')

plt.close()

### with the weighting

plt.loglog(vBS,DCrit_FM,'--s',alpha=0.7,lw=4,markersize=10,color=vcol[0])
#plt.semilogy(vBS,DCrit_FM)
plt.loglog(vBS,DCrit_rFM,'d--',lw=4,alpha=0.7,markersize=10,color=vcol[1])
#plt.semilogy(vBS,DCrit_rFM,'d')
plt.loglog(vBS,DCrit_EUC,'o--',lw=4,alpha=0.7,markersize=10,color=vcol[2])
#plt.semilogy(vBS,DCrit_EUC,'o')
plt.loglog(vBS,Crit*np.ones_like(DCrit_FMeq),'--p',alpha=0.7,lw=4,markersize=10,color=vcol[3])

plt.legend(["FMeq","rFMeq","EUCeq","NoBatch"])

plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')
plt.xlabel("Batch size",fontsize = fsize+2,weight='bold')
plt.title('Threshold k = 2 - #samples = 10000',fontsize = fsize+2,weight='bold')
plt.savefig('Weighting_K2_nsamples10000_Cd1_ns5_nobs20')
# Out:
# /data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([7,10,15,25,50,100,250,500,1000,2500])
n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.05
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 5
BS = totalSize
nmax = 500

critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []

for nmc in range(N_MC):

    X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
    
    t2 = time.time()
    out,FMw,th = dgo.Core_DGMCA(X=X,n=5,A=Ainit,kend=kend,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=totalSize, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
    t3 = time.time()
    Time.append(t3-t2)
    critA.append(EvalCriterion_eval(A0,S0,out,S0)['ca_mean'])
    
    print(nmc,BS)
    
    for r in range(len(vBS)):

        BS = vBS[r]
        
        print(nmc,BS)
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUCeq.append(t2-t1)
        critA_EUCeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUC.append(t2-t1)
        critA_EUC.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        sio.savemat("DGMCA_KEND_1_April30.mat",mdict={"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# Total size :  10000  - Number of blocks:  1
# 0 10000
# 0 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 0 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 0 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 0 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 0 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 0 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 0 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 0 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 0 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 0 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 1 2500
# 1 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 1 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 1 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 1 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 1 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 1 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 1 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 1 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 1 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 1 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 2 2500
# 2 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 2 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 2 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 2 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 2 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 2 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 2 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 2 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 2 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 2 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 3 2500
# 3 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 3 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 3 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 3 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 3 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 3 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 3 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 3 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 3 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 3 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 4 2500
# 4 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 4 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 4 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 4 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 4 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 4 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 4 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 4 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 4 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 4 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4

# %%
### Plotting the results

N_MC = 5
vBS = np.array([7,10,15,25,50,100,250,500,1000,2500])
nval = len(vBS)
ntot = N_MC*nval
totalSize = 10000

data = sio.loadmat("DGMCA_KEND_1_April30.mat")

Time_FMeq = data["Time_FMeq"]
Time_FM = data["Time_FM"]
Time_rFMeq = data["Time_rFMeq"]
Time_rFM = data["Time_rFM"]
Time_EUCeq = data["Time_EUCeq"]
Time_EUC = data["Time_EUC"]
critA_FMeq = data["critA_FMeq"]
critA_FM = data["critA_FM"]
critA_rFMeq = data["critA_rFMeq"]
critA_rFM = data["critA_rFM"]
critA_EUCeq = data["critA_EUCeq"]
critA_EUC = data["critA_EUC"]
Time = data["Time"]
critA = data["critA"]

CompTime = np.mean(Time)
Crit = np.mean(critA)
DCompTime_FMeq = np.mean(np.reshape(Time_FMeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_FMeq = np.mean(np.reshape(critA_FMeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_FM = np.mean(np.reshape(Time_FM[0:ntot],(N_MC,-1)),axis=0)
DCrit_FM = np.mean(np.reshape(critA_FM[0:ntot],(N_MC,-1)),axis=0)
DCompTime_EUCeq = np.mean(np.reshape(Time_EUCeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_EUCeq = np.mean(np.reshape(critA_EUCeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_EUC = np.mean(np.reshape(Time_EUC[0:ntot],(N_MC,-1)),axis=0)
DCrit_EUC = np.mean(np.reshape(critA_EUC[0:ntot],(N_MC,-1)),axis=0)
DCompTime_rFMeq = np.mean(np.reshape(Time_rFMeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_rFMeq = np.mean(np.reshape(critA_rFMeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_rFM = np.mean(np.reshape(Time_rFM[0:ntot],(N_MC,-1)),axis=0)
DCrit_rFM = np.mean(np.reshape(critA_rFM[0:ntot],(N_MC,-1)),axis=0)

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

plt.loglog(vBS,DCrit_FMeq,'--s',alpha=0.7,lw=4,markersize=10,color=vcol[0])
#plt.semilogy(vBS,DCrit_FM)
plt.loglog(vBS,DCrit_rFMeq,'d--',lw=4,alpha=0.7,markersize=10,color=vcol[1])
#plt.semilogy(vBS,DCrit_rFM,'d')
plt.loglog(vBS,DCrit_EUCeq,'o--',lw=4,alpha=0.7,markersize=10,color=vcol[2])
#plt.semilogy(vBS,DCrit_EUC,'o')
plt.loglog(vBS,Crit*np.ones_like(DCrit_FMeq),'--p',alpha=0.7,lw=4,markersize=10,color=vcol[3])

plt.legend(["FMeq","rFMeq","EUCeq","NoBatch"])

plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')
plt.xlabel("Batch size",fontsize = fsize+2,weight='bold')
plt.title('Threshold k = 1 - #samples = 10000',fontsize = fsize+2,weight='bold')
plt.savefig('NoWeighting_K1_nsamples10000_Cd1_ns5_nobs20')

plt.close()

### with the weighting

plt.loglog(vBS,DCrit_FM,'--s',alpha=0.7,lw=4,markersize=10,color=vcol[0])
#plt.semilogy(vBS,DCrit_FM)
plt.loglog(vBS,DCrit_rFM,'d--',lw=4,alpha=0.7,markersize=10,color=vcol[1])
#plt.semilogy(vBS,DCrit_rFM,'d')
plt.loglog(vBS,DCrit_EUC,'o--',lw=4,alpha=0.7,markersize=10,color=vcol[2])
#plt.semilogy(vBS,DCrit_EUC,'o')
plt.loglog(vBS,Crit*np.ones_like(DCrit_FMeq),'--p',alpha=0.7,lw=4,markersize=10,color=vcol[3])

plt.legend(["FMeq","rFMeq","EUCeq","NoBatch"])

plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')
plt.xlabel("Batch size",fontsize = fsize+2,weight='bold')
plt.title('Threshold k = 1 - #samples = 10000',fontsize = fsize+2,weight='bold')
plt.savefig('Weighting_K1_nsamples10000_Cd1_ns5_nobs20')
# Out:
# /data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([7,10,15,25,50,100,250,500,1000,2500])
n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.05
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 0.5

N_MC = 5
BS = totalSize
nmax = 500

critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []

for nmc in range(N_MC):

    X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
    
    t2 = time.time()
    out,FMw,th = dgo.Core_DGMCA(X=X,n=5,A=Ainit,kend=kend,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=totalSize, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
    t3 = time.time()
    Time.append(t3-t2)
    critA.append(EvalCriterion_eval(A0,S0,out,S0)['ca_mean'])
    
    print(nmc,BS)
    
    for r in range(len(vBS)):

        BS = vBS[r]
        
        print(nmc,BS)
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUCeq.append(t2-t1)
        critA_EUCeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUC.append(t2-t1)
        critA_EUC.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        sio.savemat("DGMCA_KEND_0_5_April30.mat",mdict={"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# Total size :  10000  - Number of blocks:  1
# 0 10000
# 0 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 0 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 0 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 0 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 0 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 0 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 0 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 0 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 0 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 0 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 1 2500
# 1 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 1 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 1 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 1 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 1 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 1 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 1 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 1 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 1 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 1 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 2 2500
# 2 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 2 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 2 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 2 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 2 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 2 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 2 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 2 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 2 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 2 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 3 2500
# 3 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 3 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 3 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 3 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 3 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 3 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 3 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 3 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 3 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 3 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  1
# 4 2500
# 4 7
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# Total size :  9996  - Number of blocks:  1428
# 4 10
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# Total size :  10000  - Number of blocks:  1000
# 4 15
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# Total size :  9990  - Number of blocks:  666
# 4 25
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# Total size :  10000  - Number of blocks:  400
# 4 50
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# Total size :  10000  - Number of blocks:  200
# 4 100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# Total size :  10000  - Number of blocks:  100
# 4 250
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# Total size :  10000  - Number of blocks:  40
# 4 500
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# Total size :  10000  - Number of blocks:  20
# 4 1000
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# Total size :  10000  - Number of blocks:  10
# 4 2500
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4
# Total size :  10000  - Number of blocks:  4

# %%
### Plotting the results

N_MC = 5
vBS = np.array([7,10,15,25,50,100,250,500,1000,2500])
nval = len(vBS)
ntot = N_MC*nval
totalSize = 10000

data = sio.loadmat("DGMCA_KEND_0_5_April30.mat")

Time_FMeq = data["Time_FMeq"]
Time_FM = data["Time_FM"]
Time_rFMeq = data["Time_rFMeq"]
Time_rFM = data["Time_rFM"]
Time_EUCeq = data["Time_EUCeq"]
Time_EUC = data["Time_EUC"]
critA_FMeq = data["critA_FMeq"]
critA_FM = data["critA_FM"]
critA_rFMeq = data["critA_rFMeq"]
critA_rFM = data["critA_rFM"]
critA_EUCeq = data["critA_EUCeq"]
critA_EUC = data["critA_EUC"]
Time = data["Time"]
critA = data["critA"]

CompTime = np.mean(Time)
Crit = np.mean(critA)
DCompTime_FMeq = np.mean(np.reshape(Time_FMeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_FMeq = np.mean(np.reshape(critA_FMeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_FM = np.mean(np.reshape(Time_FM[0:ntot],(N_MC,-1)),axis=0)
DCrit_FM = np.mean(np.reshape(critA_FM[0:ntot],(N_MC,-1)),axis=0)
DCompTime_EUCeq = np.mean(np.reshape(Time_EUCeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_EUCeq = np.mean(np.reshape(critA_EUCeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_EUC = np.mean(np.reshape(Time_EUC[0:ntot],(N_MC,-1)),axis=0)
DCrit_EUC = np.mean(np.reshape(critA_EUC[0:ntot],(N_MC,-1)),axis=0)
DCompTime_rFMeq = np.mean(np.reshape(Time_rFMeq[0:ntot],(N_MC,-1)),axis=0)
DCrit_rFMeq = np.mean(np.reshape(critA_rFMeq[0:ntot],(N_MC,-1)),axis=0)
DCompTime_rFM = np.mean(np.reshape(Time_rFM[0:ntot],(N_MC,-1)),axis=0)
DCrit_rFM = np.mean(np.reshape(critA_rFM[0:ntot],(N_MC,-1)),axis=0)

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

plt.loglog(vBS,DCrit_FMeq,'--s',alpha=0.7,lw=4,markersize=10,color=vcol[0])
#plt.semilogy(vBS,DCrit_FM)
plt.loglog(vBS,DCrit_rFMeq,'d--',lw=4,alpha=0.7,markersize=10,color=vcol[1])
#plt.semilogy(vBS,DCrit_rFM,'d')
plt.loglog(vBS,DCrit_EUCeq,'o--',lw=4,alpha=0.7,markersize=10,color=vcol[2])
#plt.semilogy(vBS,DCrit_EUC,'o')
plt.loglog(vBS,Crit*np.ones_like(DCrit_FMeq),'--p',alpha=0.7,lw=4,markersize=10,color=vcol[3])

plt.legend(["FMeq","rFMeq","EUCeq","NoBatch"])

plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')
plt.xlabel("Batch size",fontsize = fsize+2,weight='bold')
plt.title('Threshold k = 0.5 - #samples = 10000',fontsize = fsize+2,weight='bold')
plt.savefig('NoWeighting_K0_5_nsamples10000_Cd1_ns5_nobs20')

plt.close()

### with the weighting

plt.loglog(vBS,DCrit_FM,'--s',alpha=0.7,lw=4,markersize=10,color=vcol[0])
#plt.semilogy(vBS,DCrit_FM)
plt.loglog(vBS,DCrit_rFM,'d--',lw=4,alpha=0.7,markersize=10,color=vcol[1])
#plt.semilogy(vBS,DCrit_rFM,'d')
plt.loglog(vBS,DCrit_EUC,'o--',lw=4,alpha=0.7,markersize=10,color=vcol[2])
#plt.semilogy(vBS,DCrit_EUC,'o')
plt.loglog(vBS,Crit*np.ones_like(DCrit_FMeq),'--p',alpha=0.7,lw=4,markersize=10,color=vcol[3])

plt.legend(["FMeq","rFMeq","EUCeq","NoBatch"])

plt.ylabel("Mixing matrix criterion",fontsize = fsize+2,weight='bold')
plt.xlabel("Batch size",fontsize = fsize+2,weight='bold')
plt.title('Threshold k = 0.5 - #samples = 10000',fontsize = fsize+2,weight='bold')
plt.savefig('Weighting_K0_5_nsamples10000_Cd1_ns5_nobs20')
# Out:
# /data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family ['normal'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
