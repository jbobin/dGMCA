# %% [markdown]
# # DGMCA experiments
# ### Role played by the number of batches

# %%
import sys
sys.path.append("../src/")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
import copy as cp
#from tqdm import tqdm
import DGMCA_omp as dgo
import time
import scipy.io as sio

# %% [markdown]
# ### Full randomization or not ?

# %%
totalSize = 10000
n_s = 5 # Number of sources
n_obs = 10 # Number of observations
BlockSize = n_s
rho = 0.1 # Generalized Gaussian generation parameter
kend = 1.

X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))

nmax=500

rFM50 = []
rFM25 = []
rFM10 = []

Xr = X[:,0:1000]
BS = 25
out_omp250,FMw250,th250,Oca250,Osad250,Ocam250,Osadm250 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM25.append(Ocam250[-1])
BS = 50
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM50.append(Ocam500[-1])
BS = 10
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM10.append(Ocam500[-1])

Xr = X[:,0:2000]
BS = 25
out_omp250,FMw250,th250,Oca250,Osad250,Ocam250,Osadm250 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM25.append(Ocam250[-1])
BS = 50
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM50.append(Ocam500[-1])
BS = 10
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM10.append(Ocam500[-1])

Xr = X[:,0:4000]
BS = 25
out_omp250,FMw250,th250,Oca250,Osad250,Ocam250,Osadm250 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM25.append(Ocam250[-1])
BS = 50
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM50.append(Ocam500[-1])
BS = 10
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM10.append(Ocam500[-1])

Xr = X[:,0:8000]
BS = 25
out_omp250,FMw250,th250,Oca250,Osad250,Ocam250,Osadm250 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM25.append(Ocam250[-1])
BS = 50
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM50.append(Ocam500[-1])
BS = 10
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=Xr,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0,RandBatch=False)
rFM10.append(Ocam500[-1])

# %%
fig = plt.figure()
fig.set_size_inches(15, 10)
plt.subplot(121)
plt.semilogy(np.array(Oca250),'yd',alpha=0.1)
plt.semilogy(np.array(Ocam250),'k--',alpha=0.5,lw=8)
plt.subplot(122)
plt.semilogy(np.array(Oca500),'r.',alpha=0.1)
plt.semilogy(np.array(Ocam500),'k--',alpha=0.5,lw=8)

# %%
plt.semilogy(np.array([1000,2000,4000,8000]),np.array(rFM50),'r--',alpha=1.)
plt.semilogy(np.array([1000,2000,4000,8000]),np.array(rFM25),'k--',alpha=1.)
plt.semilogy(np.array([1000,2000,4000,8000]),np.array(rFM10),'b--',alpha=1.)

# %% [markdown]
# ### Number of iterations

# %%
totalSize = 10000
n_s = 5 # Number of sources
n_obs = 10 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
kend = 1.
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))


BS = 10

nmax=250
out_omp250,FMw250,th250,Oca250,Osad250,Ocam250,Osadm250 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

nmax=500
out_omp500,FMw500,th500,Oca500,Osad500,Ocam500,Osadm500 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

# %%
fig.set_size_inches(15, 10)
plt.subplot(121)
plt.semilogy(np.array(Oca250),'yd',alpha=0.1)
plt.subplot(122)
plt.semilogy(np.array(Oca500),'r.',alpha=0.1)

# %% [markdown]
# ### Number of channels

# %%
totalSize = 10000
n_s = 5 # Number of sources
rho = 0.1 # Generalized Gaussian generation parameter
kend = 1.

n_obs = 20 # Number of observations
Xi,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ai = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))

nns=5
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_5,FMw250_5,th250_5,Oca250_5,Osad250_5,Ocam250_5,Osadm250_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_5,FMw500_5,th500_5,Oca500_5,Osad500_5,Ocam500_5,Osadm500_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_5,FMw1000_5,th1000_5,Oca1000_5,Osad1000_5,Ocam1000_5,Osadm1000_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)


nns=10
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_10,FMw250_10,th250_10,Oca250_10,Osad250_10,Ocam250_10,Osadm250_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_10,FMw500_10,th500_10,Oca500_10,Osad500_10,Ocam500_10,Osadm500_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_10,FMw1000_10,th1000_10,Oca1000_10,Osad1000_10,Ocam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nns=20
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_20,FMw250_20,th250_20,Oca250_20,Osad250_20,Ocam250_20,Osadm250_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_20,FMw500_20,th500_20,Oca500_20,Osad500_20,Ocam500_20,Osadm500_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_20,FMw1000_20,th1000_20,Oca1000_20,Osad1000_20,Ocam1000_20,Osadm1000_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

# %%
fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(Oca250_5),'g:',alpha=0.1)
plt.subplot(132)
plt.semilogy(np.array(Oca500_5),'g:',alpha=0.1)
plt.subplot(133)
plt.semilogy(np.array(Oca1000_5),'g:',alpha=0.1)

fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(Oca250_10),'r:',alpha=0.1)
plt.subplot(132)
plt.semilogy(np.array(Oca500_10),'r:',alpha=0.1)
plt.subplot(133)
plt.semilogy(np.array(Oca1000_10),'r:',alpha=0.1)

fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(Oca250_20),'k:',alpha=0.1)
plt.subplot(132)
plt.semilogy(np.array(Oca500_20),'k:',alpha=0.1)
plt.subplot(133)
plt.semilogy(np.array(Oca1000_20),'k:',alpha=0.1)

# %%
totalSize = 10000
n_s = 5 # Number of sources
rho = 0.1 # Generalized Gaussian generation parameter
kend = 1.

n_obs = 20 # Number of observations
Xi,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ai = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))

nns=5
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_5,FMw250_5,th250_5,rOca250_5,Osad250_5,rOcam250_5,Osadm250_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_5,FMw500_5,th500_5,rOca500_5,Osad500_5,rOcam500_5,Osadm500_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_5,FMw1000_5,th1000_5,rOca1000_5,Osad1000_5,rOcam1000_5,Osadm1000_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)


nns=10
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_10,FMw250_10,th250_10,rOca250_10,Osad250_10,rOcam250_10,Osadm250_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_10,FMw500_10,th500_10,rOca500_10,Osad500_10,rOcam500_10,Osadm500_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_10,FMw1000_10,th1000_10,rOca1000_10,Osad1000_10,rOcam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nns=20
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_20,FMw250_20,th250_20,rOca250_20,Osad250_20,rOcam250_20,Osadm250_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_20,FMw500_20,th500_20,rOca500_20,Osad500_20,rOcam500_20,Osadm500_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_20,FMw1000_20,th1000_20,rOca1000_20,Osad1000_20,rOcam1000_20,Osadm1000_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

# %%
fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(rOca250_5),'g:',alpha=0.1)
plt.semilogy(rOcam250_5,'g--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(rOca500_5),'g:',alpha=0.1)
plt.semilogy(rOcam500_5,'g--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(rOca1000_5),'g:',alpha=0.1)
plt.semilogy(rOcam1000_5,'g--',lw=6)


fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(rOca250_10),'r:',alpha=0.1)
plt.semilogy(rOcam250_10,'r--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(rOca500_10),'r:',alpha=0.1)
plt.semilogy(rOcam500_10,'r--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(rOca1000_10),'r:',alpha=0.1)
plt.semilogy(rOcam1000_10,'r--',lw=6)

fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(rOca250_20),'k:',alpha=0.1)
plt.semilogy(rOcam250_20,'k--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(rOca500_20),'k:',alpha=0.1)
plt.semilogy(rOcam500_20,'k--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(rOca1000_20),'k:',alpha=0.1)
plt.semilogy(rOcam1000_20,'k--',lw=6)

# %%
totalSize = 10000
n_s = 5 # Number of sources
rho = 0.1 # Generalized Gaussian generation parameter
kend = 1.

n_obs = 20 # Number of observations
Xi,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ai = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))

nns=5
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_5,FMw250_5,th250_5,wOca250_5,Osad250_5,Ocam250_5,Osadm250_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_5,FMw500_5,th500_5,wOca500_5,Osad500_5,Ocam500_5,Osadm500_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_5,FMw1000_5,th1000_5,wOca1000_5,Osad1000_5,Ocam1000_5,Osadm1000_5 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)


nns=10
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_10,FMw250_10,th250_10,wOca250_10,Osad250_10,Ocam250_10,Osadm250_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_10,FMw500_10,th500_10,wOca500_10,Osad500_10,Ocam500_10,Osadm500_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_10,FMw1000_10,th1000_10,wOca1000_10,Osad1000_10,Ocam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nns=20
X = Xi[0:nns,:]
Ainit = Ai[0:nns,:]
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
Ai0 = A0[0:nns,:]
Ai0 = Ai0/np.maximum(0,np.linalg.norm(Ai0,axis=0))

BS = 100

nmax=250
out_omp250_20,FMw250_20,th250_20,wOca250_20,Osad250_20,Ocam250_20,Osadm250_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=500
out_omp500_20,FMw500_20,th500_20,wOca500_20,Osad500_20,Ocam500_20,Osadm500_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

nmax=1000
out_omp1000_20,FMw1000_20,th1000_20,wOca1000_20,Osad1000_20,Ocam1000_20,Osadm1000_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=Ai0)

# %%
fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(wOca250_5),'g:',alpha=0.1)
plt.semilogy(Ocam250_5,'g--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca500_5),'g:',alpha=0.1)
plt.semilogy(Ocam500_5,'g--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_5),'g:',alpha=0.1)
plt.semilogy(Ocam1000_5,'g--',lw=6)

fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(wOca250_10),'r:',alpha=0.1)
plt.semilogy(Ocam250_10,'r--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca500_10),'r:',alpha=0.1)
plt.semilogy(Ocam500_10,'r--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_10),'r:',alpha=0.1)
plt.semilogy(Ocam1000_10,'r--',lw=6)

fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(wOca250_20),'k:',alpha=0.1)
plt.semilogy(Ocam250_20,'k--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca500_20),'k:',alpha=0.1)
plt.semilogy(Ocam500_20,'k--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_20),'k:',alpha=0.1)
plt.semilogy(Ocam1000_20,'k--',lw=6)

# %% [markdown]
# ### Noise level

# %%
totalSize = 10000
n_s = 5 # Number of sources
n_obs = 10 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))

N = np.random.randn(n_obs,totalSize)

BS = 100
nmax=1000
kend = 2
noise_level = 40
sigma_noise = np.power(10.,(-noise_level/20.))*np.linalg.norm(X0,ord='fro')/np.linalg.norm(N,ord='fro')
X = X0 + sigma_noise*N
out_omp1000_40,FMw1000_40,th1000_40,wOca1000_40,Osad1000_40,Ocam1000_40,Osadm1000_40 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
kend = 2
noise_level = 20
sigma_noise = np.power(10.,(-noise_level/20.))*np.linalg.norm(X0,ord='fro')/np.linalg.norm(N,ord='fro')
X = X0 + sigma_noise*N
out_omp1000_20,FMw1000_20,th1000_20,wOca1000_20,Osad1000_20,Ocam1000_20,Osadm1000_20 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
kend = 2
noise_level = 10
sigma_noise = np.power(10.,(-noise_level/20.))*np.linalg.norm(X0,ord='fro')/np.linalg.norm(N,ord='fro')
X = X0 + sigma_noise*N
out_omp1000_10,FMw1000_10,th1000_10,wOca1000_10,Osad1000_10,Ocam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

# %%
fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(wOca1000_10),'g:',alpha=0.1)
plt.semilogy(Ocam1000_10,'g--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca1000_20),'g:',alpha=0.1)
plt.semilogy(Ocam1000_20,'g--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_40),'g:',alpha=0.1)
plt.semilogy(Ocam1000_40,'g--',lw=6)

# %% [markdown]
# ### Number of batches

# %%
totalSize = 100000
n_s = 5 # Number of sources
n_obs = 10 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
BlockSize = n_s

BS = 100
nmax=1000
kend = 2
out_omp1000_40,FMw1000_10,th1000_10,wOca1000_10,Osad1000_10,Ocam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X[:,0:1000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
out_omp1000_100,FMw1000_100,th1000_100,wOca1000_100,Osad1000_100,Ocam1000_100,Osadm1000_100 = dgo.Core_DGMCA(X=X[:,0:10000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
out_omp1000_10,FMw1000_1000,th1000_1000,wOca1000_1000,Osad1000_1000,Ocam1000_1000,Osadm1000_1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

# %%
fig = plt.figure()
fig.set_size_inches(15,15)
plt.subplot(131)
plt.semilogy(np.array(wOca1000_10),'g:',alpha=0.1)
plt.semilogy(Ocam1000_10,'g--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca1000_100),'g:',alpha=0.1)
plt.semilogy(Ocam1000_100,'g--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_1000),'g:',alpha=0.1)
plt.semilogy(Ocam1000_1000,'g--',lw=6)

# %% [markdown]
# ### Fixed nb of batches / batch size

# %%
totalSize = 1000000
n_s = 5 # Number of sources
n_obs = 10 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
BlockSize = n_s

BS = 10
nmax=1000
kend = 2
out_omp1000_40,FMw1000_10,th1000_10,wOca1000_10,Osad1000_10,Ocam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X[:,0:10000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
out_omp1000_100,FMw1000_100,th1000_100,wOca1000_100,Osad1000_100,Ocam1000_100,Osadm1000_100 = dgo.Core_DGMCA(X=X[:,0:100000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 1000
nmax=1000
out_omp1000_10,FMw1000_1000,th1000_1000,wOca1000_1000,Osad1000_1000,Ocam1000_1000,Osadm1000_1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

# %%
fig = plt.figure()
fig.set_size_inches(15,15)
plt.subplot(131)
plt.semilogy(np.array(wOca1000_10),'g:',alpha=0.1)
plt.semilogy(Ocam1000_10,'k--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca1000_100),'g:',alpha=0.1)
plt.semilogy(Ocam1000_100,'k--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_1000),'g:',alpha=0.1)
plt.semilogy(Ocam1000_1000,'k--',lw=6)

# %% [markdown]
# ### Fixed sample size

# %%
totalSize = 1000000
n_s = 5 # Number of sources
n_obs = 5 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=2,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
BlockSize = n_s

BS = 10
nmax=1000
kend = 2
out_omp1000_40,FMw1000_10,th1000_10,wOca1000_10,Osad1000_10,Ocam1000_10,Osadm1000_10 = dgo.Core_DGMCA(X=X[:,0:10000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
out_omp1000_100,FMw1000_100,th1000_100,wOca1000_100,Osad1000_100,Ocam1000_100,Osadm1000_100 = dgo.Core_DGMCA(X=X[:,0:10000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 1000
nmax=1000
out_omp1000_10,FMw1000_1000,th1000_1000,wOca1000_1000,Osad1000_1000,Ocam1000_1000,Osadm1000_1000 = dgo.Core_DGMCA(X=X[:,0:10000],n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

# %%
fig = plt.figure()
fig.set_size_inches(15,15)
plt.subplot(131)
plt.semilogy(np.array(wOca1000_10),'g:',alpha=0.1)
plt.semilogy(Ocam1000_10,'k--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca1000_100),'g:',alpha=0.1)
plt.semilogy(Ocam1000_100,'k--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_1000),'g:',alpha=0.1)
plt.semilogy(Ocam1000_1000,'k--',lw=6)

# %% [markdown]
# ### Choix du seuil

# %%
totalSize = 10000
n_s = 5 # Number of sources
n_obs = 10 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=1,alpha=rho)
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))


BS = 100
nmax=1000
kend = 2
out_omp1000_2,FMw1000_2,th1000_2,wOca1000_2,Osad1000_2,Ocam1000_2,Osadm1000_2 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
kend = 1
out_omp1000_1,FMw1000_1,th1000_1,wOca1000_1,Osad1000_1,Ocam1000_1,Osadm1000_1 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

BS = 100
nmax=1000
kend = 0.5
out_omp1000_05,FMw1000_05,th1000_05,wOca1000_05,Osad1000_05,Ocam1000_05,Osadm1000_05 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)

# %%
fig.set_size_inches(5, 30)
plt.subplot(131)
plt.semilogy(np.array(wOca1000_05),'g:',alpha=0.1)
plt.semilogy(Ocam1000_05,'g--',lw=6)
plt.subplot(132)
plt.semilogy(np.array(wOca1000_1),'g:',alpha=0.1)
plt.semilogy(Ocam1000_1,'g--',lw=6)
plt.subplot(133)
plt.semilogy(np.array(wOca1000_2),'g:',alpha=0.1)
plt.semilogy(Ocam1000_2,'g--',lw=6)

# %% [markdown]
# ### NBatches = 10000 // we have to check the number of channels as well

# %%
import DGMCA_omp as dgo
import DGMCA as dg
from imp import reload
import time
reload(dgo)

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
n_s = 5 # Number of sources
n_obs = 5 # Number of observations
rho = 0.1 # Generalized Gaussian generation parameter
BlockSize =  n_s
nmax = 100
kend = 0.1

X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=2,alpha=rho)

Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))

BS = 1000
out_omp1000,FMw1000,th1000,Oca1000,Osad1000,Ocam1000,Osadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 100
out_omp100,FMw100,th1000,Oca100,Osad100,Ocam100,Osadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 10
out_omp10,FMw10,th10,Oca10,Osad10,Ocam10,Osadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='FM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 1000
out_omp1000,FMw1000,th1000,rOca1000,rOsad1000,rOcam1000,rOsadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 100
out_omp100,FMw100,th1000,rOca100,rOsad100,rOcam100,rOsadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 10
out_omp10,FMw10,th10,rOca10,rOsad10,rOcam10,rOsadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=True,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 1000
out_omp1000,FMw1000,th1000,wOca1000,wOsad1000,wOcam1000,wOsadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 100
out_omp100,FMw100,th1000,wOca100,wOsad100,wOcam100,wOsadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 10
out_omp10,FMw10,th10,wOca10,wOsad10,wOcam10,wOsadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 1000
out_omp1000,FMw1000,th1000,wrOca1000,wrOsad1000,wrOcam1000,wrOsadm1000 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 100
out_omp100,FMw100,th1000,wrOca100,wrOsad100,wrOcam100,wrOsadm100 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
BS = 10
out_omp10,FMw10,th10,wrOca10,wrOsad10,wrOcam10,wrOsadm10 = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,q_f=0.1,AggMeth='rFM',Equal=False,nmax=nmax,BlockSize = BlockSize,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.,A0=A0)
print("DONE")

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

niter = -1
bins = np.linspace(-2.5, -0.5, 40)
plt.hist(np.log10(Oca1000[niter]),bins,alpha=0.3,density=True,color=vcol[0])
plt.hist(np.log10(Oca100[niter]),bins,alpha=0.3,density=True,color=vcol[1])
plt.hist(np.log10(Oca10[niter]),bins,alpha=0.3,density=True,color=vcol[2])
#plt.hist(np.log10(Ocam10[98]),bins,alpha=0.3,density=True)
plt.axvline(x=np.log10(Ocam1000[niter]),color=vcol[0],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(Ocam100[niter]),color=vcol[1],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(Ocam10[niter]),color=vcol[2],lw=8,alpha=0.75,linestyle=':')
plt.xlabel("CA")
plt.legend(['1000','100','10'])
fig = plt.gcf()
fig.set_size_inches(15, 10)
if save:
    fig.savefig('CaHist_FM_rho0_1.png', dpi=300, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

niter = -1
bins = np.linspace(-2.5, -0.5, 40)
plt.hist(np.log10(wOca1000[niter]),bins,alpha=0.3,density=True,color=vcol[0])
plt.hist(np.log10(wOca100[niter]),bins,alpha=0.3,density=True,color=vcol[1])
plt.hist(np.log10(wOca10[niter]),bins,alpha=0.3,density=True,color=vcol[2])
#plt.hist(np.log10(Ocam10[98]),bins,alpha=0.3,density=True)
plt.axvline(x=np.log10(wOcam1000[niter]),color=vcol[0],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(wOcam100[niter]),color=vcol[1],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(wOcam10[niter]),color=vcol[2],lw=8,alpha=0.75,linestyle=':')
plt.xlabel("CA")
plt.legend(['1000','100','10'])
fig = plt.gcf()
fig.set_size_inches(15, 10)
if save:
    fig.savefig('CaHist_wFM_rho0_1.png', dpi=300, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

niter = -1
bins = np.linspace(-2.5, -0.5, 40)
plt.hist(np.log10(rOca1000[niter]),bins,alpha=0.3,density=True,color=vcol[0])
plt.hist(np.log10(rOca100[niter]),bins,alpha=0.3,density=True,color=vcol[1])
plt.hist(np.log10(rOca10[niter]),bins,alpha=0.3,density=True,color=vcol[2])
#plt.hist(np.log10(Ocam10[98]),bins,alpha=0.3,density=True)
plt.axvline(x=np.log10(rOcam1000[niter]),color=vcol[0],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(rOcam100[niter]),color=vcol[1],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(rOcam10[niter]),color=vcol[2],lw=8,alpha=0.75,linestyle=':')
plt.xlabel("CA")
plt.legend(['1000','100','10'])
fig = plt.gcf()
fig.set_size_inches(15, 10)
if save:
    fig.savefig('CaHist_rFM_rho0_1.png', dpi=300, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)

# %%
save = False

fsize = 16
vcol = ['mediumseagreen','crimson','steelblue','darkmagenta','burlywood','khaki','lightblue','darkseagreen','deepskyblue','forestgreen','gold','indianred','midnightblue','olive','orangered','orchid','red','steelblue']
font = {'family' : 'normal',
            'weight' : 'bold',
            'size'   : fsize}
plt.rc('font', **font)
plt.rcParams["figure.figsize"] = (15,10)

niter = -1
bins = np.linspace(-2.5, -0.5, 40)
plt.hist(np.log10(wrOca1000[niter]),bins,alpha=0.3,density=True,color=vcol[0])
plt.hist(np.log10(wrOca100[niter]),bins,alpha=0.3,density=True,color=vcol[1])
plt.hist(np.log10(wrOca10[niter]),bins,alpha=0.3,density=True,color=vcol[2])
#plt.hist(np.log10(Ocam10[98]),bins,alpha=0.3,density=True)
plt.axvline(x=np.log10(wrOcam1000[niter]),color=vcol[0],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(wrOcam100[niter]),color=vcol[1],lw=8,alpha=0.75,linestyle=':')
plt.axvline(x=np.log10(wrOcam10[niter]),color=vcol[2],lw=8,alpha=0.75,linestyle=':')
plt.xlabel("CA")
plt.legend(['1000','100','10'])
fig = plt.gcf()
fig.set_size_inches(15, 10)
if save:
    fig.savefig('CaHist_rFM_rho0_1.png', dpi=300, facecolor='w', edgecolor='w',orientation='portrait', format='png',transparent=True, bbox_inches='tight', pad_inches=0.5,frameon=True)
