# %%
import sys
sys.path.append("../src/")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
from DGMCA_omp import mp as mp
# from DGMCA_omp import *
# from GMCA import Core_GMCA as gmca
import copy as cp
#from tqdm import tqdm
import time
import scipy.io as sio

# %%
import astropy.io.fits as pyf
I = pyf.open("input.fits")[0].data
J = pyf.open("output.fits")[0].data

# %%
print(np.shape(I))
from FrechetMean import FrechetMean as fm
out = fm(I[:,1,:],w=np.ones((3,1))/3.,t=0.5,itmax=100)
#out = mp.FrechetMean(I[:,:,0:3],np.array([0.3,0.3,0.3]))
#out = out[:,1]/np.sum(out[:,1])

plt.plot(I[:,1,0:3])
plt.plot(out,'o')
# Out:
# (8, 4, 3)
