# %%
import sys
sys.path.append("../src/")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
import copy as cp
#from tqdm import tqdm
import DGMCA_omp as dgo
import time
import scipy.io as sio
from sklearn.decomposition import MiniBatchDictionaryLearning
import GMCA as gmca

# %% [markdown]
# ## BS = 10

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([5,10,100,250,500,1000,2500,5000,10000])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.1
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

BS = 10
N_MC = 10
nmax = 1000

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):

    for r in range(len(vBS)):

        totalSize = vBS[r]*BS
        totalSize.astype('int')        
        
        X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=3,alpha=rho)
    
        R = np.dot(X,X.T)
        D,V = lng.eig(R)
        AInit = V[:,0:n_s]
    
        print(nmc,totalSize,BS)
        
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=1,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        t1 = time.time()
        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        t2 = time.time()
        Time_ODL.append(t2-t1)
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        
        sio.savemat("DGMCA_BS10_BatchNumber_ns5_rho01_Cd3_June3.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# 0 50 10
# 0 100 10
# 0 1000 10
# 0 2500 10
# 0 5000 10
# 0 10000 10
# 0 25000 10
# 0 50000 10
# 0 100000 10
# 1 50 10
# 1 100 10
# 1 1000 10
# /data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 1 2500 10
# 1 5000 10
# 1 10000 10
# 1 25000 10
# 1 50000 10
# 1 100000 10
# 2 50 10
# 2 100 10
# 2 1000 10
# 2 2500 10
# 2 5000 10
# 2 10000 10
# 2 25000 10
# 2 50000 10
# 2 100000 10
# 3 50 10
# 3 100 10
# 3 1000 10
# 3 2500 10
# 3 5000 10
# 3 10000 10
# 3 25000 10
# 3 50000 10
# 3 100000 10
# 4 50 10
# 4 100 10
# 4 1000 10
# 4 2500 10
# 4 5000 10
# 4 10000 10
# 4 25000 10
# 4 50000 10
# 4 100000 10
# 5 50 10
# 5 100 10
# 5 1000 10
# 5 2500 10
# 5 5000 10
# 5 10000 10
# 5 25000 10
# 5 50000 10
# 5 100000 10
# 6 50 10
# 6 100 10
# 6 1000 10
# 6 2500 10
# 6 5000 10
# 6 10000 10
# 6 25000 10
# 6 50000 10
# 6 100000 10
# 7 50 10
# 7 100 10
# 7 1000 10
# 7 2500 10
# 7 5000 10
# 7 10000 10
# 7 25000 10
# 7 50000 10
# 7 100000 10
# 8 50 10
# 8 100 10
# 8 1000 10
# 8 2500 10
# 8 5000 10
# 8 10000 10
# 8 25000 10
# 8 50000 10
# 8 100000 10
# 9 50 10
# 9 100 10
# 9 1000 10
# 9 2500 10
# 9 5000 10
# 9 10000 10
# 9 25000 10
# 9 50000 10
# 9 100000 10

# %% [markdown]
# ## BS = 25

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([5,10,100,250,500,1000,2500,5000,10000])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.1
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

BS = 25
N_MC = 10
nmax = 1000

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):

    for r in range(len(vBS)):

        totalSize = vBS[r]*BS
        totalSize.astype('int')
        
        X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=3,alpha=rho)
    
        R = np.dot(X,X.T)
        D,V = lng.eig(R)
        AInit = V[:,0:n_s]
    
        print(nmc,totalSize,BS)
        
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=1,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        t1 = time.time()
        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        t2 = time.time()
        Time_ODL.append(t2-t1)
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        
        sio.savemat("DGMCA_BS25_BatchNumber_ns5_rho01_Cd3_June3.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# 0 125 25
# 0 250 25
# /data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 0 2500 25
# 0 6250 25
# 0 12500 25
# 0 25000 25
# 0 62500 25
# 0 125000 25
# 0 250000 25
# 1 125 25
# 1 250 25
# 1 2500 25
# 1 6250 25
# 1 12500 25
# 1 25000 25
# 1 62500 25
# 1 125000 25
# 1 250000 25
# 2 125 25
# 2 250 25
# 2 2500 25
# 2 6250 25
# 2 12500 25
# 2 25000 25
# 2 62500 25
# 2 125000 25
# 2 250000 25
# 3 125 25
# 3 250 25
# 3 2500 25
# 3 6250 25
# 3 12500 25
# 3 25000 25
# 3 62500 25
# 3 125000 25
# 3 250000 25
# 4 125 25
# 4 250 25
# 4 2500 25
# 4 6250 25
# 4 12500 25
# 4 25000 25
# 4 62500 25
# 4 125000 25
# 4 250000 25
# 5 125 25
# 5 250 25
# 5 2500 25
# 5 6250 25
# 5 12500 25
# 5 25000 25
# 5 62500 25
# 5 125000 25
# 5 250000 25
# 6 125 25
# 6 250 25
# 6 2500 25
# 6 6250 25
# 6 12500 25
# 6 25000 25
# 6 62500 25
# 6 125000 25
# 6 250000 25
# 7 125 25
# 7 250 25
# 7 2500 25
# 7 6250 25
# 7 12500 25
# 7 25000 25
# 7 62500 25
# 7 125000 25
# 7 250000 25
# 8 125 25
# 8 250 25
# 8 2500 25
# 8 6250 25
# 8 12500 25
# 8 25000 25
# 8 62500 25
# 8 125000 25
# 8 250000 25
# 9 125 25
# 9 250 25
# 9 2500 25
# 9 6250 25
# 9 12500 25
# 9 25000 25
# 9 62500 25
# 9 125000 25
# 9 250000 25

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([5,10,100,250,500,1000,2500,5000,10000])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.1
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

BS = 100
N_MC = 10
nmax = 1000

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):

    for r in range(len(vBS)):

        totalSize = vBS[r]*BS
        totalSize.astype('int')
        
        X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=3,alpha=rho)
    
        R = np.dot(X,X.T)
        D,V = lng.eig(R)
        AInit = V[:,0:n_s]
    
        print(nmc,totalSize,BS)
        
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=1,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        t1 = time.time()
        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        t2 = time.time()
        Time_ODL.append(t2-t1)
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        
        sio.savemat("DGMCA_BS100_BatchNumber_ns5_rho01_Cd3_June3.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# 0 500 100
# 0 1000 100
# 0 10000 100
# 0 25000 100
# 0 50000 100
# 0 100000 100
# 0 250000 100
# 0 500000 100
# 0 1000000 100
# 1 500 100
# 1 1000 100
# 1 10000 100
# 1 25000 100
# 1 50000 100
# 1 100000 100
# /data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# 1 250000 100
# 1 500000 100
# 1 1000000 100
# 2 500 100
# 2 1000 100
# 2 10000 100
# 2 25000 100
# 2 50000 100
# 2 100000 100
# 2 250000 100
# 2 500000 100
# 2 1000000 100
# 3 500 100
# 3 1000 100
# 3 10000 100
# 3 25000 100
# 3 50000 100
# 3 100000 100
# 3 250000 100
# 3 500000 100
# 3 1000000 100
# 4 500 100
# 4 1000 100
# 4 10000 100
# 4 25000 100
# 4 50000 100
# 4 100000 100
# 4 250000 100
# 4 500000 100
# 4 1000000 100
# 5 500 100
# 5 1000 100
# 5 10000 100
# 5 25000 100
# 5 50000 100
# 5 100000 100
# 5 250000 100
# 5 500000 100
# 5 1000000 100
# 6 500 100
# 6 1000 100
# 6 10000 100
# 6 25000 100
# 6 50000 100
# 6 100000 100
# 6 250000 100
# 6 500000 100
# 6 1000000 100
# 7 500 100
# 7 1000 100
# 7 10000 100
# 7 25000 100
# 7 50000 100
# 7 100000 100
# 7 250000 100
# 7 500000 100
# 7 1000000 100
# 8 500 100
# 8 1000 100
# 8 10000 100
# 8 25000 100
# 8 50000 100
# 8 100000 100
# 8 250000 100
# 8 500000 100
# 8 1000000 100
# 9 500 100
# 9 1000 100
# 9 10000 100
# 9 25000 100
# 9 50000 100
# 9 100000 100
# 9 250000 100
# 9 500000 100
# 9 1000000 100

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([5,10,100,250,500,1000,2500,5000,10000])

n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.1
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

BS = 1000
N_MC = 10
nmax = 1000

critA = []
critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []
critA_ODL = []
Time_ODL = []

for nmc in range(N_MC):

    for r in range(len(vBS)):

        totalSize = vBS[r]*BS
        totalSize.astype('int')
        
        X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=3,alpha=rho)
    
        R = np.dot(X,X.T)
        D,V = lng.eig(R)
        AInit = V[:,0:n_s]
    
        print(nmc,totalSize,BS)
        
        Res = gmca.GMCA(X,n=n_s,mints=1.,nmax=250,L0=1,UseP=1,verb=0,Init=0,SCOpt=0,Kmax=1)
        critA.append(EvalCriterion_eval(A0,S0,Res['mixmat'],S0)['ca_mean'])
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,FullyRandom=True,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        t1 = time.time()
        dico = MiniBatchDictionaryLearning(n_components=n_s, alpha=0.05, n_iter=10000,batch_size=BS,fit_algorithm='cd')
        V = dico.fit(X.T).components_        
        t2 = time.time()
        Time_ODL.append(t2-t1)
        critA_ODL.append(EvalCriterion_eval(A0,S0,V.T,S0)['ca_mean'])
        
        sio.savemat("DGMCA_BS1000_BatchNumber_ns5_rho01_Cd3_June3.mat",mdict={"Time_ODL":Time_ODL,"critA_ODL":critA_ODL,"nmc":nmc,"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
# 0 5000 1000
# 0 10000 1000
# 0 100000 1000
# 0 250000 1000
# 0 500000 1000
# 0 1000000 1000
# 0 2500000 1000
# 0 5000000 1000
# 0 10000000 1000
# 1 5000 1000
# 1 10000 1000
# 1 100000 1000
# 1 250000 1000
# 1 500000 1000
# 1 1000000 1000
# 1 2500000 1000
# 1 5000000 1000
# 1 10000000 1000
# 2 5000 1000
# 2 10000 1000
# 2 100000 1000
# 2 250000 1000
# 2 500000 1000
# 2 1000000 1000
# 2 2500000 1000
# 2 5000000 1000
# 2 10000000 1000
# 3 5000 1000
# 3 10000 1000
# 3 100000 1000
# 3 250000 1000
# 3 500000 1000
# 3 1000000 1000
# 3 2500000 1000
# 3 5000000 1000
# 3 10000000 1000
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-5-a61aeaee1813>", line 79, in <module>
#     V = dico.fit(X.T).components_
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/decomposition/dict_learning.py", line 1274, in fit
#     return_n_iter=True)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/decomposition/dict_learning.py", line 741, in dict_learning_online
#     alpha=alpha, n_jobs=n_jobs).T
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/decomposition/dict_learning.py", line 290, in sparse_encode
#     verbose=verbose)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/decomposition/dict_learning.py", line 134, in _sparse_encode
#     clf.fit(dictionary.T, X.T, check_input=check_input)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py", line 752, in fit
#     check_input=False)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py", line 473, in enet_path
#     tol, rng, random, positive)
#   File "sklearn/linear_model/cd_fast.pyx", line 694, in sklearn.linear_model.cd_fast.enet_coordinate_descent_gram
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/numpy/core/numeric.py", line 424, in asarray
#     def asarray(a, dtype=None, order=None):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1863, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/IPython/core/ultratb.py", line 1095, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/IPython/core/ultratb.py", line 311, in wrapped
#     return f(*args, **kwargs)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/IPython/core/ultratb.py", line 345, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/inspect.py", line 1480, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/inspect.py", line 1442, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/site-packages/IPython/core/ultratb.py", line 177, in findsource
#     lines = linecache.getlines(file, globals_dict)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/linecache.py", line 47, in getlines
#     return updatecache(filename, module_globals)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/tokenize.py", line 454, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/tokenize.py", line 423, in detect_encoding
#     first = read_or_stop()
#   File "/data_diskd/Python-3.6.2/BUILD_DIR/lib/python3.6/tokenize.py", line 381, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ---------------------------------------------------------------------------
