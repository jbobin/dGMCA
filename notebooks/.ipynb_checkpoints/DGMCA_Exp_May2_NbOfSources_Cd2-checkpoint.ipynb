# %%
import sys
sys.path.append("../src/")
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from utils_dgmca import divisorGenerator
from utils_dgmca import Make_Experiment_GG
from misc_dgmca import *
import copy as cp
#from tqdm import tqdm
import DGMCA_omp as dgo
import time
import scipy.io as sio

# %%
## ns = 5

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([12,15,25,50,100,250,500,1000,2500])
n_s = 5 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.05
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 25
BS = totalSize
nmax = 1000

critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []

for nmc in range(N_MC):

    X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=2,alpha=rho)
    
    t2 = time.time()
    out,FMw,th = dgo.Core_DGMCA(X=X,n=5,A=Ainit,kend=kend,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=totalSize, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
    t3 = time.time()
    Time.append(t3-t2)
    critA.append(EvalCriterion_eval(A0,S0,out,S0)['ca_mean'])
    
    print(nmc,BS)
    
    for r in range(len(vBS)):

        BS = vBS[r]
        
        print(nmc,BS)
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUCeq.append(t2-t1)
        critA_EUCeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUC.append(t2-t1)
        critA_EUC.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        sio.savemat("DGMCA_Nobs20_ns5_Cd2_May20.mat",mdict={"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
# Out:
#
# Time for a single iteration : 5.583198308944702
# Remaining time : 5024.878478050232
#
# Time for a single iteration : 4.777958631515503
# Remaining time : 3822.3669052124023
#
# Time for a single iteration : 5.900938272476196
# Remaining time : 4130.656790733337
#
# Time for a single iteration : 2.4461092948913574
# Remaining time : 1467.6655769348145
#
# Time for a single iteration : 4.485240459442139
# Remaining time : 2242.6202297210693
#
# Time for a single iteration : 3.2920913696289062
# Remaining time : 1316.8365478515625
#
# Time for a single iteration : 6.120772361755371
# Remaining time : 1836.2317085266113
#
# Time for a single iteration : 5.377931833267212
# Remaining time : 1075.5863666534424
#
# Time for a single iteration : 5.190248250961304
# Remaining time : 519.0248250961304
#
# Time for a single iteration : 6.193946838378906
# Remaining time : 0.0
# 0 10000
# 0 12
#
# Time for a single iteration : 0.18327832221984863
# Remaining time : 164.95048999786377
#
# Time for a single iteration : 0.16612839698791504
# Remaining time : 132.90271759033203
#
# Time for a single iteration : 0.20705366134643555
# Remaining time : 144.93756294250488
#
# Time for a single iteration : 0.16993212699890137
# Remaining time : 101.95927619934082
#
# Time for a single iteration : 0.15457749366760254
# Remaining time : 77.28874683380127
#
# Time for a single iteration : 0.2190539836883545
# Remaining time : 87.6215934753418
#
# Time for a single iteration : 0.2144463062286377
# Remaining time : 64.33389186859131
#
# Time for a single iteration : 0.1658179759979248
# Remaining time : 33.16359519958496
#
# Time for a single iteration : 0.2149033546447754
# Remaining time : 21.49033546447754
#
# Time for a single iteration : 0.18930840492248535
# Remaining time : 0.0
#
# Time for a single iteration : 0.08604574203491211
# Remaining time : 77.4411678314209
#
# Time for a single iteration : 0.17635536193847656
# Remaining time : 141.08428955078125
#
# Time for a single iteration : 0.1796586513519287
# Remaining time : 125.7610559463501
#
# Time for a single iteration : 0.16913223266601562
# Remaining time : 101.47933959960938
#
# Time for a single iteration : 0.17626023292541504
# Remaining time : 88.13011646270752
#
# Time for a single iteration : 0.1494286060333252
# Remaining time : 59.77144241333008
#
# Time for a single iteration : 0.17666196823120117
# Remaining time : 52.99859046936035
#
# Time for a single iteration : 0.15944361686706543
# Remaining time : 31.888723373413086
#
# Time for a single iteration : 0.1489715576171875
# Remaining time : 14.89715576171875
#
# Time for a single iteration : 0.17910528182983398
# Remaining time : 0.0
#
# Time for a single iteration : 0.2077350616455078
# Remaining time : 186.96155548095703
#
# Time for a single iteration : 0.1606290340423584
# Remaining time : 128.50322723388672
#
# Time for a single iteration : 0.19338560104370117
# Remaining time : 135.36992073059082
#
# Time for a single iteration : 0.21967411041259766
# Remaining time : 131.8044662475586
#
# Time for a single iteration : 0.15668845176696777
# Remaining time : 78.34422588348389
#
# Time for a single iteration : 0.17384576797485352
# Remaining time : 69.5383071899414
#
# Time for a single iteration : 0.25698137283325195
# Remaining time : 77.09441184997559
#
# Time for a single iteration : 0.17499876022338867
# Remaining time : 34.999752044677734
#
# Time for a single iteration : 0.05610346794128418
# Remaining time : 5.610346794128418
#
# Time for a single iteration : 0.18024682998657227
# Remaining time : 0.0
#
# Time for a single iteration : 0.22997522354125977
# Remaining time : 206.9777011871338
#
# Time for a single iteration : 0.16934943199157715
# Remaining time : 135.47954559326172
#
# Time for a single iteration : 0.14131689071655273
# Remaining time : 98.92182350158691
#
# Time for a single iteration : 0.19754433631896973
# Remaining time : 118.52660179138184
#
# Time for a single iteration : 0.16738104820251465
# Remaining time : 83.69052410125732
#
# Time for a single iteration : 0.1501445770263672
# Remaining time : 60.057830810546875
#
# Time for a single iteration : 0.15797805786132812
# Remaining time : 47.39341735839844
#
# Time for a single iteration : 0.14036297798156738
# Remaining time : 28.072595596313477
#
# Time for a single iteration : 0.16533446311950684
# Remaining time : 16.533446311950684
#
# Time for a single iteration : 0.2020092010498047
# Remaining time : 0.0
#
# Time for a single iteration : 0.06928563117980957
# Remaining time : 62.35706806182861
#
# Time for a single iteration : 0.03740859031677246
# Remaining time : 29.92687225341797
#
# Time for a single iteration : 0.07500815391540527
# Remaining time : 52.50570774078369
#
# Time for a single iteration : 0.03433513641357422
# Remaining time : 20.60108184814453
#
# Time for a single iteration : 0.02254486083984375
# Remaining time : 11.272430419921875
#
# Time for a single iteration : 0.060959815979003906
# Remaining time : 24.383926391601562
#
# Time for a single iteration : 0.06603193283081055
# Remaining time : 19.809579849243164
#
# Time for a single iteration : 0.042958974838256836
# Remaining time : 8.591794967651367
#
# Time for a single iteration : 0.08294034004211426
# Remaining time : 8.294034004211426
#
# Time for a single iteration : 0.0428919792175293
# Remaining time : 0.0
#
# Time for a single iteration : 0.07373809814453125
# Remaining time : 66.36428833007812
#
# Time for a single iteration : 0.07841300964355469
# Remaining time : 62.73040771484375
#
# Time for a single iteration : 0.07073187828063965
# Remaining time : 49.512314796447754
#
# Time for a single iteration : 0.06482195854187012
# Remaining time : 38.89317512512207
#
# Time for a single iteration : 0.054914236068725586
# Remaining time : 27.457118034362793
#
# Time for a single iteration : 0.07985663414001465
# Remaining time : 31.94265365600586
#
# Time for a single iteration : 0.035970211029052734
# Remaining time : 10.79106330871582
#
# Time for a single iteration : 0.08523440361022949
# Remaining time : 17.0468807220459
#
# Time for a single iteration : 0.06486153602600098
# Remaining time : 6.486153602600098
#
# Time for a single iteration : 0.048772335052490234
# Remaining time : 0.0
# 0 15
#
# Time for a single iteration : 0.04114866256713867
# Remaining time : 37.033796310424805
#
# Time for a single iteration : 0.14362359046936035
# Remaining time : 114.89887237548828
#
# Time for a single iteration : 0.18095755577087402
# Remaining time : 126.67028903961182
#
# Time for a single iteration : 0.14780855178833008
# Remaining time : 88.68513107299805
#
# Time for a single iteration : 0.14395737648010254
# Remaining time : 71.97868824005127
#
# Time for a single iteration : 0.16703438758850098
# Remaining time : 66.81375503540039
#
# Time for a single iteration : 0.1657695770263672
# Remaining time : 49.730873107910156
#
# Time for a single iteration : 0.15720582008361816
# Remaining time : 31.441164016723633
#
# Time for a single iteration : 0.14572978019714355
# Remaining time : 14.572978019714355
#
# Time for a single iteration : 0.15659308433532715
# Remaining time : 0.0
#
# Time for a single iteration : 0.1568591594696045
# Remaining time : 141.17324352264404
#
# Time for a single iteration : 0.15161490440368652
# Remaining time : 121.29192352294922
#
# Time for a single iteration : 0.14188265800476074
# Remaining time : 99.31786060333252
#
# Time for a single iteration : 0.11725473403930664
# Remaining time : 70.35284042358398
#
# Time for a single iteration : 0.11217856407165527
# Remaining time : 56.08928203582764
#
# Time for a single iteration : 0.13427734375
# Remaining time : 53.7109375
#
# Time for a single iteration : 0.16954517364501953
# Remaining time : 50.86355209350586
#
# Time for a single iteration : 0.16397428512573242
# Remaining time : 32.794857025146484
#
# Time for a single iteration : 0.1410074234008789
# Remaining time : 14.10074234008789
#
# Time for a single iteration : 0.1699843406677246
# Remaining time : 0.0
#
# Time for a single iteration : 0.18343067169189453
# Remaining time : 165.08760452270508
#
# Time for a single iteration : 0.06948709487915039
# Remaining time : 55.58967590332031
#
# Time for a single iteration : 0.050406694412231445
# Remaining time : 35.28468608856201
#
# Time for a single iteration : 0.18857049942016602
# Remaining time : 113.14229965209961
#
# Time for a single iteration : 0.14291024208068848
# Remaining time : 71.45512104034424
#
# Time for a single iteration : 0.12578916549682617
# Remaining time : 50.31566619873047
#
# Time for a single iteration : 0.15688824653625488
# Remaining time : 47.066473960876465
#
# Time for a single iteration : 0.13673758506774902
# Remaining time : 27.347517013549805
#
# Time for a single iteration : 0.189927339553833
# Remaining time : 18.9927339553833
#
# Time for a single iteration : 0.17478275299072266
# Remaining time : 0.0
#
# Time for a single iteration : 0.1284198760986328
# Remaining time : 115.57788848876953
#
# Time for a single iteration : 0.12550830841064453
# Remaining time : 100.40664672851562
#
# Time for a single iteration : 0.16000699996948242
# Remaining time : 112.0048999786377
#
# Time for a single iteration : 0.13825488090515137
# Remaining time : 82.95292854309082
#
# Time for a single iteration : 0.18900227546691895
# Remaining time : 94.50113773345947
#
# Time for a single iteration : 0.14634275436401367
# Remaining time : 58.53710174560547
#
# Time for a single iteration : 0.15702557563781738
# Remaining time : 47.107672691345215
#
# Time for a single iteration : 0.14362454414367676
# Remaining time : 28.72490882873535
#
# Time for a single iteration : 0.13797998428344727
# Remaining time : 13.797998428344727
#
# Time for a single iteration : 0.09220218658447266
# Remaining time : 0.0
#
# Time for a single iteration : 0.03719949722290039
# Remaining time : 33.47954750061035
#
# Time for a single iteration : 0.07048177719116211
# Remaining time : 56.38542175292969
#
# Time for a single iteration : 0.0387423038482666
# Remaining time : 27.11961269378662
#
# Time for a single iteration : 0.051413536071777344
# Remaining time : 30.848121643066406
#
# Time for a single iteration : 0.06343388557434082
# Remaining time : 31.71694278717041
#
# Time for a single iteration : 0.05904793739318848
# Remaining time : 23.61917495727539
#
# Time for a single iteration : 0.03313469886779785
# Remaining time : 9.940409660339355
#
# Time for a single iteration : 0.03969836235046387
# Remaining time : 7.939672470092773
#
# Time for a single iteration : 0.041222333908081055
# Remaining time : 4.1222333908081055
#
# Time for a single iteration : 0.04691314697265625
# Remaining time : 0.0
#
# Time for a single iteration : 0.03641033172607422
# Remaining time : 32.7692985534668
#
# Time for a single iteration : 0.03493809700012207
# Remaining time : 27.950477600097656
#
# Time for a single iteration : 0.016977310180664062
# Remaining time : 11.884117126464844
#
# Time for a single iteration : 0.016985177993774414
# Remaining time : 10.191106796264648
#
# Time for a single iteration : 0.015606403350830078
# Remaining time : 7.803201675415039
#
# Time for a single iteration : 0.060975074768066406
# Remaining time : 24.390029907226562
#
# Time for a single iteration : 0.0788428783416748
# Remaining time : 23.65286350250244
#
# Time for a single iteration : 0.053225040435791016
# Remaining time : 10.645008087158203
#
# Time for a single iteration : 0.040961503982543945
# Remaining time : 4.0961503982543945
#
# Time for a single iteration : 0.0520014762878418
# Remaining time : 0.0
# 0 25
#
# Time for a single iteration : 0.08010005950927734
# Remaining time : 72.09005355834961
#
# Time for a single iteration : 0.07594466209411621
# Remaining time : 60.75572967529297
#
# Time for a single iteration : 0.08899879455566406
# Remaining time : 62.299156188964844
#
# Time for a single iteration : 0.13382387161254883
# Remaining time : 80.2943229675293
#
# Time for a single iteration : 0.10950684547424316
# Remaining time : 54.75342273712158
#
# Time for a single iteration : 0.06704020500183105
# Remaining time : 26.816082000732422
#
# Time for a single iteration : 0.07000303268432617
# Remaining time : 21.00090980529785
#
# Time for a single iteration : 0.1179952621459961
# Remaining time : 23.59905242919922
#
# Time for a single iteration : 0.08439207077026367
# Remaining time : 8.439207077026367
#
# Time for a single iteration : 0.07766914367675781
# Remaining time : 0.0
#
# Time for a single iteration : 0.10202360153198242
# Remaining time : 91.82124137878418
#
# Time for a single iteration : 0.11244416236877441
# Remaining time : 89.95532989501953
#
# Time for a single iteration : 0.12235546112060547
# Remaining time : 85.64882278442383
#
# Time for a single iteration : 0.11936736106872559
# Remaining time : 71.62041664123535
#
# Time for a single iteration : 0.11742424964904785
# Remaining time : 58.712124824523926
#
# Time for a single iteration : 0.08337879180908203
# Remaining time : 33.35151672363281
#
# Time for a single iteration : 0.07963156700134277
# Remaining time : 23.889470100402832
#
# Time for a single iteration : 0.06053614616394043
# Remaining time : 12.107229232788086
#
# Time for a single iteration : 0.10840630531311035
# Remaining time : 10.840630531311035
#
# Time for a single iteration : 0.10581040382385254
# Remaining time : 0.0
#
# Time for a single iteration : 0.1314253807067871
# Remaining time : 118.2828426361084
#
# Time for a single iteration : 0.07801485061645508
# Remaining time : 62.41188049316406
#
# Time for a single iteration : 0.05866575241088867
# Remaining time : 41.06602668762207
#
# Time for a single iteration : 0.12712359428405762
# Remaining time : 76.27415657043457
#
# Time for a single iteration : 0.05932211875915527
# Remaining time : 29.661059379577637
#
# Time for a single iteration : 0.07367944717407227
# Remaining time : 29.471778869628906
#
# Time for a single iteration : 0.07921814918518066
# Remaining time : 23.7654447555542
#
# Time for a single iteration : 0.10432100296020508
# Remaining time : 20.864200592041016
#
# Time for a single iteration : 0.07896971702575684
# Remaining time : 7.896971702575684
#
# Time for a single iteration : 0.028493165969848633
# Remaining time : 0.0
#
# Time for a single iteration : 0.08646035194396973
# Remaining time : 77.81431674957275
#
# Time for a single iteration : 0.08823466300964355
# Remaining time : 70.58773040771484
#
# Time for a single iteration : 0.11067724227905273
# Remaining time : 77.47406959533691
#
# Time for a single iteration : 0.06460738182067871
# Remaining time : 38.76442909240723
#
# Time for a single iteration : 0.08141326904296875
# Remaining time : 40.706634521484375
#
# Time for a single iteration : 0.09529328346252441
# Remaining time : 38.117313385009766
#
# Time for a single iteration : 0.10496282577514648
# Remaining time : 31.488847732543945
#
# Time for a single iteration : 0.09731435775756836
# Remaining time : 19.462871551513672
#
# Time for a single iteration : 0.08535027503967285
# Remaining time : 8.535027503967285
#
# Time for a single iteration : 0.0985569953918457
# Remaining time : 0.0
#
# Time for a single iteration : 0.026047468185424805
# Remaining time : 23.442721366882324
#
# Time for a single iteration : 0.025560855865478516
# Remaining time : 20.448684692382812
#
# Time for a single iteration : 0.04417991638183594
# Remaining time : 30.925941467285156
#
# Time for a single iteration : 0.03098583221435547
# Remaining time : 18.59149932861328
#
# Time for a single iteration : 0.0380861759185791
# Remaining time : 19.04308795928955
#
# Time for a single iteration : 0.04054427146911621
# Remaining time : 16.217708587646484
#
# Time for a single iteration : 0.02603888511657715
# Remaining time : 7.8116655349731445
#
# Time for a single iteration : 0.0256650447845459
# Remaining time : 5.13300895690918
#
# Time for a single iteration : 0.047466278076171875
# Remaining time : 4.7466278076171875
#
# Time for a single iteration : 0.03471088409423828
# Remaining time : 0.0
#
# Time for a single iteration : 0.020000457763671875
# Remaining time : 18.000411987304688
#
# Time for a single iteration : 0.026969432830810547
# Remaining time : 21.575546264648438
#
# Time for a single iteration : 0.05372476577758789
# Remaining time : 37.60733604431152
#
# Time for a single iteration : 0.019957542419433594
# Remaining time : 11.974525451660156
#
# Time for a single iteration : 0.048169612884521484
# Remaining time : 24.084806442260742
#
# Time for a single iteration : 0.030364513397216797
# Remaining time : 12.145805358886719
#
# Time for a single iteration : 0.03288626670837402
# Remaining time : 9.865880012512207
#
# Time for a single iteration : 0.04968976974487305
# Remaining time : 9.93795394897461
#
# Time for a single iteration : 0.03517007827758789
# Remaining time : 3.517007827758789
#
# Time for a single iteration : 0.022240877151489258
# Remaining time : 0.0
# 0 50
#
# Time for a single iteration : 0.0539851188659668
# Remaining time : 48.58660697937012
#
# Time for a single iteration : 0.07054424285888672
# Remaining time : 56.435394287109375
#
# Time for a single iteration : 0.06368422508239746
# Remaining time : 44.57895755767822
#
# Time for a single iteration : 0.05095362663269043
# Remaining time : 30.572175979614258
#
# Time for a single iteration : 0.03735017776489258
# Remaining time : 18.67508888244629
#
# Time for a single iteration : 0.05659341812133789
# Remaining time : 22.637367248535156
#
# Time for a single iteration : 0.07027888298034668
# Remaining time : 21.083664894104004
#
# Time for a single iteration : 0.051001548767089844
# Remaining time : 10.200309753417969
#
# Time for a single iteration : 0.04990077018737793
# Remaining time : 4.990077018737793
#
# Time for a single iteration : 0.0448305606842041
# Remaining time : 0.0
#
# Time for a single iteration : 0.0621182918548584
# Remaining time : 55.90646266937256
#
# Time for a single iteration : 0.09599590301513672
# Remaining time : 76.79672241210938
#
# Time for a single iteration : 0.05413627624511719
# Remaining time : 37.89539337158203
#
# Time for a single iteration : 0.10404419898986816
# Remaining time : 62.4265193939209
#
# Time for a single iteration : 0.0618901252746582
# Remaining time : 30.9450626373291
#
# Time for a single iteration : 0.07618975639343262
# Remaining time : 30.475902557373047
#
# Time for a single iteration : 0.0823514461517334
# Remaining time : 24.70543384552002
#
# Time for a single iteration : 0.032012939453125
# Remaining time : 6.402587890625
#
# Time for a single iteration : 0.03975272178649902
# Remaining time : 3.9752721786499023
#
# Time for a single iteration : 0.05119729042053223
# Remaining time : 0.0
#
# Time for a single iteration : 0.0469508171081543
# Remaining time : 42.25573539733887
#
# Time for a single iteration : 0.018584489822387695
# Remaining time : 14.867591857910156
#
# Time for a single iteration : 0.048871755599975586
# Remaining time : 34.21022891998291
#
# Time for a single iteration : 0.06698322296142578
# Remaining time : 40.18993377685547
#
# Time for a single iteration : 0.1330883502960205
# Remaining time : 66.54417514801025
#
# Time for a single iteration : 0.04237079620361328
# Remaining time : 16.948318481445312
#
# Time for a single iteration : 0.04434967041015625
# Remaining time : 13.304901123046875
#
# Time for a single iteration : 0.04514932632446289
# Remaining time : 9.029865264892578
#
# Time for a single iteration : 0.08457684516906738
# Remaining time : 8.457684516906738
#
# Time for a single iteration : 0.0627593994140625
# Remaining time : 0.0
#
# Time for a single iteration : 0.05183219909667969
# Remaining time : 46.64897918701172
#
# Time for a single iteration : 0.05384707450866699
# Remaining time : 43.077659606933594
#
# Time for a single iteration : 0.06496119499206543
# Remaining time : 45.4728364944458
#
# Time for a single iteration : 0.040255069732666016
# Remaining time : 24.15304183959961
#
# Time for a single iteration : 0.04388856887817383
# Remaining time : 21.944284439086914
#
# Time for a single iteration : 0.0639808177947998
# Remaining time : 25.592327117919922
#
# Time for a single iteration : 0.04958939552307129
# Remaining time : 14.876818656921387
#
# Time for a single iteration : 0.04781317710876465
# Remaining time : 9.56263542175293
#
# Time for a single iteration : 0.05704450607299805
# Remaining time : 5.704450607299805
#
# Time for a single iteration : 0.07233977317810059
# Remaining time : 0.0
#
# Time for a single iteration : 0.0346372127532959
# Remaining time : 31.17349147796631
#
# Time for a single iteration : 0.022037506103515625
# Remaining time : 17.6300048828125
#
# Time for a single iteration : 0.04331707954406738
# Remaining time : 30.321955680847168
#
# Time for a single iteration : 0.038216590881347656
# Remaining time : 22.929954528808594
#
# Time for a single iteration : 0.01874518394470215
# Remaining time : 9.372591972351074
#
# Time for a single iteration : 0.018136262893676758
# Remaining time : 7.254505157470703
#
# Time for a single iteration : 0.04250454902648926
# Remaining time : 12.751364707946777
#
# Time for a single iteration : 0.0312654972076416
# Remaining time : 6.25309944152832
#
# Time for a single iteration : 0.028935909271240234
# Remaining time : 2.8935909271240234
#
# Time for a single iteration : 0.04684805870056152
# Remaining time : 0.0
#
# Time for a single iteration : 0.025213003158569336
# Remaining time : 22.691702842712402
#
# Time for a single iteration : 0.017704486846923828
# Remaining time : 14.163589477539062
#
# Time for a single iteration : 0.021797657012939453
# Remaining time : 15.258359909057617
#
# Time for a single iteration : 0.047773122787475586
# Remaining time : 28.66387367248535
#
# Time for a single iteration : 0.03440213203430176
# Remaining time : 17.20106601715088
#
# Time for a single iteration : 0.02831101417541504
# Remaining time : 11.324405670166016
#
# Time for a single iteration : 0.0532834529876709
# Remaining time : 15.98503589630127
#
# Time for a single iteration : 0.04223895072937012
# Remaining time : 8.447790145874023
#
# Time for a single iteration : 0.028392314910888672
# Remaining time : 2.839231491088867
#
# Time for a single iteration : 0.03127026557922363
# Remaining time : 0.0
# 0 100
#
# Time for a single iteration : 0.07376408576965332
# Remaining time : 66.38767719268799
#
# Time for a single iteration : 0.05120682716369629
# Remaining time : 40.96546173095703
#
# Time for a single iteration : 0.03409719467163086
# Remaining time : 23.8680362701416
#
# Time for a single iteration : 0.03919243812561035
# Remaining time : 23.51546287536621
#
# Time for a single iteration : 0.038567543029785156
# Remaining time : 19.283771514892578
#
# Time for a single iteration : 0.06578397750854492
# Remaining time : 26.31359100341797
#
# Time for a single iteration : 0.027068138122558594
# Remaining time : 8.120441436767578
#
# Time for a single iteration : 0.061103105545043945
# Remaining time : 12.220621109008789
#
# Time for a single iteration : 0.05228590965270996
# Remaining time : 5.228590965270996
#
# Time for a single iteration : 0.0650796890258789
# Remaining time : 0.0
#
# Time for a single iteration : 0.04587244987487793
# Remaining time : 41.28520488739014
#
# Time for a single iteration : 0.04624485969543457
# Remaining time : 36.995887756347656
#
# Time for a single iteration : 0.03294229507446289
# Remaining time : 23.059606552124023
#
# Time for a single iteration : 0.05420231819152832
# Remaining time : 32.52139091491699
#
# Time for a single iteration : 0.07843160629272461
# Remaining time : 39.215803146362305
#
# Time for a single iteration : 0.07898569107055664
# Remaining time : 31.594276428222656
#
# Time for a single iteration : 0.04897308349609375
# Remaining time : 14.691925048828125
#
# Time for a single iteration : 0.04789328575134277
# Remaining time : 9.578657150268555
#
# Time for a single iteration : 0.06656670570373535
# Remaining time : 6.656670570373535
#
# Time for a single iteration : 0.0645601749420166
# Remaining time : 0.0
#
# Time for a single iteration : 0.017432689666748047
# Remaining time : 15.689420700073242
#
# Time for a single iteration : 0.01551508903503418
# Remaining time : 12.412071228027344
#
# Time for a single iteration : 0.013844013214111328
# Remaining time : 9.69080924987793
#
# Time for a single iteration : 0.05961966514587402
# Remaining time : 35.771799087524414
#
# Time for a single iteration : 0.0713496208190918
# Remaining time : 35.6748104095459
#
# Time for a single iteration : 0.06947970390319824
# Remaining time : 27.791881561279297
#
# Time for a single iteration : 0.06261610984802246
# Remaining time : 18.78483295440674
#
# Time for a single iteration : 0.04593682289123535
# Remaining time : 9.18736457824707
#
# Time for a single iteration : 0.03936338424682617
# Remaining time : 3.936338424682617
#
# Time for a single iteration : 0.045424699783325195
# Remaining time : 0.0
#
# Time for a single iteration : 0.04404735565185547
# Remaining time : 39.64262008666992
#
# Time for a single iteration : 0.045938968658447266
# Remaining time : 36.75117492675781
#
# Time for a single iteration : 0.0626380443572998
# Remaining time : 43.84663105010986
#
# Time for a single iteration : 0.03517603874206543
# Remaining time : 21.105623245239258
#
# Time for a single iteration : 0.06658816337585449
# Remaining time : 33.294081687927246
#
# Time for a single iteration : 0.05044865608215332
# Remaining time : 20.179462432861328
#
# Time for a single iteration : 0.03995156288146973
# Remaining time : 11.985468864440918
#
# Time for a single iteration : 0.05959606170654297
# Remaining time : 11.919212341308594
#
# Time for a single iteration : 0.055489301681518555
# Remaining time : 5.5489301681518555
#
# Time for a single iteration : 0.05783414840698242
# Remaining time : 0.0
#
# Time for a single iteration : 0.025868654251098633
# Remaining time : 23.28178882598877
#
# Time for a single iteration : 0.03195810317993164
# Remaining time : 25.566482543945312
#
# Time for a single iteration : 0.03483414649963379
# Remaining time : 24.383902549743652
#
# Time for a single iteration : 0.030999183654785156
# Remaining time : 18.599510192871094
#
# Time for a single iteration : 0.03092789649963379
# Remaining time : 15.463948249816895
#
# Time for a single iteration : 0.04470324516296387
# Remaining time : 17.881298065185547
#
# Time for a single iteration : 0.039807796478271484
# Remaining time : 11.942338943481445
#
# Time for a single iteration : 0.02251744270324707
# Remaining time : 4.503488540649414
#
# Time for a single iteration : 0.03708457946777344
# Remaining time : 3.7084579467773438
#
# Time for a single iteration : 0.015028238296508789
# Remaining time : 0.0
#
# Time for a single iteration : 0.048529863357543945
# Remaining time : 43.67687702178955
#
# Time for a single iteration : 0.042611122131347656
# Remaining time : 34.088897705078125
#
# Time for a single iteration : 0.02516317367553711
# Remaining time : 17.614221572875977
#
# Time for a single iteration : 0.04473280906677246
# Remaining time : 26.839685440063477
#
# Time for a single iteration : 0.01762986183166504
# Remaining time : 8.81493091583252
#
# Time for a single iteration : 0.021956920623779297
# Remaining time : 8.782768249511719
#
# Time for a single iteration : 0.024558544158935547
# Remaining time : 7.367563247680664
#
# Time for a single iteration : 0.028155088424682617
# Remaining time : 5.631017684936523
#
# Time for a single iteration : 0.02495408058166504
# Remaining time : 2.495408058166504
#
# Time for a single iteration : 0.025232791900634766
# Remaining time : 0.0
# 0 250
#
# Time for a single iteration : 0.04409980773925781
# Remaining time : 39.68982696533203
#
# Time for a single iteration : 0.036327362060546875
# Remaining time : 29.0618896484375
#
# Time for a single iteration : 0.04394698143005371
# Remaining time : 30.762887001037598
#
# Time for a single iteration : 0.04579520225524902
# Remaining time : 27.477121353149414
#
# Time for a single iteration : 0.03027033805847168
# Remaining time : 15.13516902923584
#
# Time for a single iteration : 0.03216242790222168
# Remaining time : 12.864971160888672
#
# Time for a single iteration : 0.027796030044555664
# Remaining time : 8.3388090133667
#
# Time for a single iteration : 0.06089329719543457
# Remaining time : 12.178659439086914
#
# Time for a single iteration : 0.030994415283203125
# Remaining time : 3.0994415283203125
#
# Time for a single iteration : 0.05938720703125
# Remaining time : 0.0
#
# Time for a single iteration : 0.03595900535583496
# Remaining time : 32.363104820251465
#
# Time for a single iteration : 0.02935028076171875
# Remaining time : 23.480224609375
#
# Time for a single iteration : 0.05575442314147949
# Remaining time : 39.028096199035645
#
# Time for a single iteration : 0.029776334762573242
# Remaining time : 17.865800857543945
#
# Time for a single iteration : 0.03972792625427246
# Remaining time : 19.86396312713623
#
# Time for a single iteration : 0.05224609375
# Remaining time : 20.8984375
#
# Time for a single iteration : 0.06913375854492188
# Remaining time : 20.740127563476562
#
# Time for a single iteration : 0.05818939208984375
# Remaining time : 11.63787841796875
#
# Time for a single iteration : 0.058896541595458984
# Remaining time : 5.889654159545898
#
# Time for a single iteration : 0.04194188117980957
# Remaining time : 0.0
#
# Time for a single iteration : 0.06002449989318848
# Remaining time : 54.02204990386963
#
# Time for a single iteration : 0.03970956802368164
# Remaining time : 31.767654418945312
#
# Time for a single iteration : 0.03277158737182617
# Remaining time : 22.94011116027832
#
# Time for a single iteration : 0.026868820190429688
# Remaining time : 16.121292114257812
#
# Time for a single iteration : 0.03699827194213867
# Remaining time : 18.499135971069336
#
# Time for a single iteration : 0.04672098159790039
# Remaining time : 18.688392639160156
#
# Time for a single iteration : 0.03904366493225098
# Remaining time : 11.713099479675293
#
# Time for a single iteration : 0.030251502990722656
# Remaining time : 6.050300598144531
#
# Time for a single iteration : 0.014128684997558594
# Remaining time : 1.4128684997558594
#
# Time for a single iteration : 0.013128995895385742
# Remaining time : 0.0
#
# Time for a single iteration : 0.0407865047454834
# Remaining time : 36.70785427093506
#
# Time for a single iteration : 0.031019926071166992
# Remaining time : 24.815940856933594
#
# Time for a single iteration : 0.05231118202209473
# Remaining time : 36.61782741546631
#
# Time for a single iteration : 0.037232398986816406
# Remaining time : 22.339439392089844
#
# Time for a single iteration : 0.02653360366821289
# Remaining time : 13.266801834106445
#
# Time for a single iteration : 0.05622363090515137
# Remaining time : 22.489452362060547
#
# Time for a single iteration : 0.04353499412536621
# Remaining time : 13.060498237609863
#
# Time for a single iteration : 0.0587613582611084
# Remaining time : 11.75227165222168
#
# Time for a single iteration : 0.04930424690246582
# Remaining time : 4.930424690246582
#
# Time for a single iteration : 0.04811692237854004
# Remaining time : 0.0
#
# Time for a single iteration : 0.0665731430053711
# Remaining time : 59.915828704833984
#
# Time for a single iteration : 0.023864030838012695
# Remaining time : 19.091224670410156
#
# Time for a single iteration : 0.04004335403442383
# Remaining time : 28.03034782409668
#
# Time for a single iteration : 0.03660869598388672
# Remaining time : 21.96521759033203
#
# Time for a single iteration : 0.03796029090881348
# Remaining time : 18.98014545440674
#
# Time for a single iteration : 0.029902219772338867
# Remaining time : 11.960887908935547
#
# Time for a single iteration : 0.048207759857177734
# Remaining time : 14.46232795715332
#
# Time for a single iteration : 0.038848161697387695
# Remaining time : 7.769632339477539
#
# Time for a single iteration : 0.04308176040649414
# Remaining time : 4.308176040649414
#
# Time for a single iteration : 0.03763127326965332
# Remaining time : 0.0
#
# Time for a single iteration : 0.05939221382141113
# Remaining time : 53.45299243927002
#
# Time for a single iteration : 0.04079127311706543
# Remaining time : 32.633018493652344
#
# Time for a single iteration : 0.022347688674926758
# Remaining time : 15.64338207244873
#
# Time for a single iteration : 0.029036521911621094
# Remaining time : 17.421913146972656
#
# Time for a single iteration : 0.05228996276855469
# Remaining time : 26.144981384277344
#
# Time for a single iteration : 0.0214383602142334
# Remaining time : 8.57534408569336
#
# Time for a single iteration : 0.030017852783203125
# Remaining time : 9.005355834960938
#
# Time for a single iteration : 0.06793880462646484
# Remaining time : 13.587760925292969
#
# Time for a single iteration : 0.03437089920043945
# Remaining time : 3.4370899200439453
#
# Time for a single iteration : 0.04190659523010254
# Remaining time : 0.0
# 0 500
#
# Time for a single iteration : 0.04475212097167969
# Remaining time : 40.27690887451172
#
# Time for a single iteration : 0.07063102722167969
# Remaining time : 56.50482177734375
#
# Time for a single iteration : 0.040997982025146484
# Remaining time : 28.69858741760254
#
# Time for a single iteration : 0.05606508255004883
# Remaining time : 33.6390495300293
#
# Time for a single iteration : 0.051956892013549805
# Remaining time : 25.978446006774902
#
# Time for a single iteration : 0.05510377883911133
# Remaining time : 22.04151153564453
#
# Time for a single iteration : 0.08617424964904785
# Remaining time : 25.852274894714355
#
# Time for a single iteration : 0.10786795616149902
# Remaining time : 21.573591232299805
#
# Time for a single iteration : 0.09772992134094238
# Remaining time : 9.772992134094238
#
# Time for a single iteration : 0.0677039623260498
# Remaining time : 0.0
#
# Time for a single iteration : 0.06862425804138184
# Remaining time : 61.76183223724365
#
# Time for a single iteration : 0.04532313346862793
# Remaining time : 36.258506774902344
#
# Time for a single iteration : 0.04308199882507324
# Remaining time : 30.15739917755127
#
# Time for a single iteration : 0.06676554679870605
# Remaining time : 40.05932807922363
#
# Time for a single iteration : 0.047841787338256836
# Remaining time : 23.920893669128418
#
# Time for a single iteration : 0.04117083549499512
# Remaining time : 16.468334197998047
#
# Time for a single iteration : 0.06461048126220703
# Remaining time : 19.38314437866211
#
# Time for a single iteration : 0.05092334747314453
# Remaining time : 10.184669494628906
#
# Time for a single iteration : 0.058344364166259766
# Remaining time : 5.834436416625977
#
# Time for a single iteration : 0.037781476974487305
# Remaining time : 0.0
#
# Time for a single iteration : 0.046976566314697266
# Remaining time : 42.27890968322754
#
# Time for a single iteration : 0.08595156669616699
# Remaining time : 68.7612533569336
#
# Time for a single iteration : 0.06938028335571289
# Remaining time : 48.56619834899902
#
# Time for a single iteration : 0.05947446823120117
# Remaining time : 35.6846809387207
#
# Time for a single iteration : 0.06865978240966797
# Remaining time : 34.329891204833984
#
# Time for a single iteration : 0.05198955535888672
# Remaining time : 20.795822143554688
#
# Time for a single iteration : 0.04472851753234863
# Remaining time : 13.41855525970459
#
# Time for a single iteration : 0.046853065490722656
# Remaining time : 9.370613098144531
#
# Time for a single iteration : 0.049423933029174805
# Remaining time : 4.9423933029174805
#
# Time for a single iteration : 0.027757644653320312
# Remaining time : 0.0
#
# Time for a single iteration : 0.0202028751373291
# Remaining time : 18.18258762359619
#
# Time for a single iteration : 0.01931619644165039
# Remaining time : 15.452957153320312
#
# Time for a single iteration : 0.06662249565124512
# Remaining time : 46.63574695587158
#
# Time for a single iteration : 0.0479736328125
# Remaining time : 28.7841796875
#
# Time for a single iteration : 0.05078125
# Remaining time : 25.390625
#
# Time for a single iteration : 0.051085710525512695
# Remaining time : 20.434284210205078
#
# Time for a single iteration : 0.10627126693725586
# Remaining time : 31.881380081176758
#
# Time for a single iteration : 0.08479666709899902
# Remaining time : 16.959333419799805
#
# Time for a single iteration : 0.03884577751159668
# Remaining time : 3.884577751159668
#
# Time for a single iteration : 0.08040499687194824
# Remaining time : 0.0
#
# Time for a single iteration : 0.0399930477142334
# Remaining time : 35.99374294281006
#
# Time for a single iteration : 0.03172039985656738
# Remaining time : 25.376319885253906
#
# Time for a single iteration : 0.0472719669342041
# Remaining time : 33.09037685394287
#
# Time for a single iteration : 0.06872892379760742
# Remaining time : 41.23735427856445
#
# Time for a single iteration : 0.03466200828552246
# Remaining time : 17.33100414276123
#
# Time for a single iteration : 0.04536175727844238
# Remaining time : 18.144702911376953
#
# Time for a single iteration : 0.03489089012145996
# Remaining time : 10.467267036437988
#
# Time for a single iteration : 0.042064666748046875
# Remaining time : 8.412933349609375
#
# Time for a single iteration : 0.03966784477233887
# Remaining time : 3.9667844772338867
#
# Time for a single iteration : 0.028848886489868164
# Remaining time : 0.0
#
# Time for a single iteration : 0.03795170783996582
# Remaining time : 34.15653705596924
#
# Time for a single iteration : 0.03729534149169922
# Remaining time : 29.836273193359375
#
# Time for a single iteration : 0.06481480598449707
# Remaining time : 45.37036418914795
#
# Time for a single iteration : 0.04443955421447754
# Remaining time : 26.663732528686523
#
# Time for a single iteration : 0.038513898849487305
# Remaining time : 19.256949424743652
#
# Time for a single iteration : 0.034126996994018555
# Remaining time : 13.650798797607422
#
# Time for a single iteration : 0.03991556167602539
# Remaining time : 11.974668502807617
#
# Time for a single iteration : 0.06496238708496094
# Remaining time : 12.992477416992188
#
# Time for a single iteration : 0.050746917724609375
# Remaining time : 5.0746917724609375
#
# Time for a single iteration : 0.05516457557678223
# Remaining time : 0.0
# 0 1000
#
# Time for a single iteration : 0.09309172630310059
# Remaining time : 83.78255367279053
#
# Time for a single iteration : 0.08686661720275879
# Remaining time : 69.49329376220703
#
# Time for a single iteration : 0.09176039695739746
# Remaining time : 64.23227787017822
#
# Time for a single iteration : 0.08379793167114258
# Remaining time : 50.27875900268555
#
# Time for a single iteration : 0.0897207260131836
# Remaining time : 44.8603630065918
#
# Time for a single iteration : 0.1004793643951416
# Remaining time : 40.19174575805664
#
# Time for a single iteration : 0.08905196189880371
# Remaining time : 26.715588569641113
#
# Time for a single iteration : 0.09064078330993652
# Remaining time : 18.128156661987305
#
# Time for a single iteration : 0.09096026420593262
# Remaining time : 9.096026420593262
#
# Time for a single iteration : 0.09492278099060059
# Remaining time : 0.0
#
# Time for a single iteration : 0.1027829647064209
# Remaining time : 92.50466823577881
#
# Time for a single iteration : 0.09694766998291016
# Remaining time : 77.55813598632812
#
# Time for a single iteration : 0.10998749732971191
# Remaining time : 76.99124813079834
#
# Time for a single iteration : 0.1277599334716797
# Remaining time : 76.65596008300781
#
# Time for a single iteration : 0.08516669273376465
# Remaining time : 42.583346366882324
#
# Time for a single iteration : 0.060012102127075195
# Remaining time : 24.004840850830078
#
# Time for a single iteration : 0.03368854522705078
# Remaining time : 10.106563568115234
#
# Time for a single iteration : 0.09684896469116211
# Remaining time : 19.369792938232422
#
# Time for a single iteration : 0.08994126319885254
# Remaining time : 8.994126319885254
#
# Time for a single iteration : 0.07938790321350098
# Remaining time : 0.0
#
# Time for a single iteration : 0.11455774307250977
# Remaining time : 103.10196876525879
#
# Time for a single iteration : 0.0919194221496582
# Remaining time : 73.53553771972656
#
# Time for a single iteration : 0.09055161476135254
# Remaining time : 63.38613033294678
#
# Time for a single iteration : 0.09417176246643066
# Remaining time : 56.5030574798584
#
# Time for a single iteration : 0.10123682022094727
# Remaining time : 50.61841011047363
#
# Time for a single iteration : 0.08473086357116699
# Remaining time : 33.8923454284668
#
# Time for a single iteration : 0.14513778686523438
# Remaining time : 43.54133605957031
#
# Time for a single iteration : 0.12271952629089355
# Remaining time : 24.54390525817871
#
# Time for a single iteration : 0.0934443473815918
# Remaining time : 9.34443473815918
#
# Time for a single iteration : 0.08620905876159668
# Remaining time : 0.0
#
# Time for a single iteration : 0.13692688941955566
# Remaining time : 123.2342004776001
#
# Time for a single iteration : 0.09594178199768066
# Remaining time : 76.75342559814453
#
# Time for a single iteration : 0.09817647933959961
# Remaining time : 68.72353553771973
#
# Time for a single iteration : 0.09268784523010254
# Remaining time : 55.61270713806152
#
# Time for a single iteration : 0.10407781600952148
# Remaining time : 52.03890800476074
#
# Time for a single iteration : 0.09540128707885742
# Remaining time : 38.16051483154297
#
# Time for a single iteration : 0.10507678985595703
# Remaining time : 31.52303695678711
#
# Time for a single iteration : 0.08943414688110352
# Remaining time : 17.886829376220703
#
# Time for a single iteration : 0.08056116104125977
# Remaining time : 8.056116104125977
#
# Time for a single iteration : 0.10184884071350098
# Remaining time : 0.0
#
# Time for a single iteration : 0.09716105461120605
# Remaining time : 87.44494915008545
#
# Time for a single iteration : 0.08191466331481934
# Remaining time : 65.53173065185547
#
# Time for a single iteration : 0.09896326065063477
# Remaining time : 69.27428245544434
#
# Time for a single iteration : 0.07913064956665039
# Remaining time : 47.478389739990234
#
# Time for a single iteration : 0.10788273811340332
# Remaining time : 53.94136905670166
#
# Time for a single iteration : 0.08663439750671387
# Remaining time : 34.65375900268555
#
# Time for a single iteration : 0.09760093688964844
# Remaining time : 29.28028106689453
#
# Time for a single iteration : 0.03980731964111328
# Remaining time : 7.961463928222656
#
# Time for a single iteration : 0.08971905708312988
# Remaining time : 8.971905708312988
#
# Time for a single iteration : 0.09914946556091309
# Remaining time : 0.0
#
# Time for a single iteration : 0.09138679504394531
# Remaining time : 82.24811553955078
#
# Time for a single iteration : 0.10310244560241699
# Remaining time : 82.4819564819336
#
# Time for a single iteration : 0.09301328659057617
# Remaining time : 65.10930061340332
#
# Time for a single iteration : 0.08200263977050781
# Remaining time : 49.20158386230469
#
# Time for a single iteration : 0.09148335456848145
# Remaining time : 45.74167728424072
#
# Time for a single iteration : 0.09605097770690918
# Remaining time : 38.42039108276367
#
# Time for a single iteration : 0.10149526596069336
# Remaining time : 30.448579788208008
#
# Time for a single iteration : 0.08684229850769043
# Remaining time : 17.368459701538086
#
# Time for a single iteration : 0.09001398086547852
# Remaining time : 9.001398086547852
#
# Time for a single iteration : 0.08912801742553711
# Remaining time : 0.0
# 0 2500
#
# Time for a single iteration : 0.4024229049682617
# Remaining time : 362.18061447143555
#
# Time for a single iteration : 0.38912248611450195
# Remaining time : 311.29798889160156
#
# Time for a single iteration : 0.43767619132995605
# Remaining time : 306.37333393096924
#
# Time for a single iteration : 0.3934464454650879
# Remaining time : 236.06786727905273
#
# Time for a single iteration : 0.1352529525756836
# Remaining time : 67.6264762878418
#
# Time for a single iteration : 0.3565516471862793
# Remaining time : 142.62065887451172
#
# Time for a single iteration : 0.36957812309265137
# Remaining time : 110.87343692779541
#
# Time for a single iteration : 0.3742184638977051
# Remaining time : 74.84369277954102
#
# Time for a single iteration : 0.4019660949707031
# Remaining time : 40.19660949707031
#
# Time for a single iteration : 0.35889625549316406
# Remaining time : 0.0
#
# Time for a single iteration : 0.3612539768218994
# Remaining time : 325.1285791397095
#
# Time for a single iteration : 0.3921194076538086
# Remaining time : 313.6955261230469
#
# Time for a single iteration : 0.4574275016784668
# Remaining time : 320.19925117492676
#
# Time for a single iteration : 0.40309786796569824
# Remaining time : 241.85872077941895
#
# Time for a single iteration : 0.40183019638061523
# Remaining time : 200.91509819030762
#
# Time for a single iteration : 0.45714235305786133
# Remaining time : 182.85694122314453
#
# Time for a single iteration : 0.3698849678039551
# Remaining time : 110.96549034118652
#
# Time for a single iteration : 0.40856361389160156
# Remaining time : 81.71272277832031
#
# Time for a single iteration : 0.39391326904296875
# Remaining time : 39.391326904296875
#
# Time for a single iteration : 0.4864380359649658
# Remaining time : 0.0
#
# Time for a single iteration : 0.36764001846313477
# Remaining time : 330.8760166168213
#
# Time for a single iteration : 0.35831165313720703
# Remaining time : 286.6493225097656
#
# Time for a single iteration : 0.35345935821533203
# Remaining time : 247.42155075073242
#
# Time for a single iteration : 0.3574972152709961
# Remaining time : 214.49832916259766
#
# Time for a single iteration : 0.3742666244506836
# Remaining time : 187.1333122253418
#
# Time for a single iteration : 0.3636658191680908
# Remaining time : 145.46632766723633
#
# Time for a single iteration : 0.2752375602722168
# Remaining time : 82.57126808166504
#
# Time for a single iteration : 0.3733537197113037
# Remaining time : 74.67074394226074
#
# Time for a single iteration : 0.4482731819152832
# Remaining time : 44.82731819152832
#
# Time for a single iteration : 0.4506185054779053
# Remaining time : 0.0
#
# Time for a single iteration : 0.4010908603668213
# Remaining time : 360.98177433013916
#
# Time for a single iteration : 0.47013187408447266
# Remaining time : 376.1054992675781
#
# Time for a single iteration : 0.3978137969970703
# Remaining time : 278.4696578979492
#
# Time for a single iteration : 0.3507041931152344
# Remaining time : 210.42251586914062
#
# Time for a single iteration : 0.44713735580444336
# Remaining time : 223.56867790222168
#
# Time for a single iteration : 0.44184303283691406
# Remaining time : 176.73721313476562
#
# Time for a single iteration : 0.39928650856018066
# Remaining time : 119.7859525680542
#
# Time for a single iteration : 0.4392051696777344
# Remaining time : 87.84103393554688
#
# Time for a single iteration : 0.36632633209228516
# Remaining time : 36.632633209228516
#
# Time for a single iteration : 0.38645124435424805
# Remaining time : 0.0
#
# Time for a single iteration : 0.405712366104126
# Remaining time : 365.1411294937134
#
# Time for a single iteration : 0.4341158866882324
# Remaining time : 347.29270935058594
#
# Time for a single iteration : 0.37223052978515625
# Remaining time : 260.5613708496094
#
# Time for a single iteration : 0.4993455410003662
# Remaining time : 299.6073246002197
#
# Time for a single iteration : 0.4771914482116699
# Remaining time : 238.59572410583496
#
# Time for a single iteration : 0.37062788009643555
# Remaining time : 148.25115203857422
#
# Time for a single iteration : 0.42939305305480957
# Remaining time : 128.81791591644287
#
# Time for a single iteration : 0.3638880252838135
# Remaining time : 72.7776050567627
#
# Time for a single iteration : 0.5741236209869385
# Remaining time : 57.41236209869385
#
# Time for a single iteration : 0.3728630542755127
# Remaining time : 0.0
#
# Time for a single iteration : 0.3575139045715332
# Remaining time : 321.7625141143799
#
# Time for a single iteration : 0.48564696311950684
# Remaining time : 388.51757049560547
#
# Time for a single iteration : 0.40032029151916504
# Remaining time : 280.2242040634155
#
# Time for a single iteration : 0.43558597564697266
# Remaining time : 261.3515853881836
#
# Time for a single iteration : 0.4566183090209961
# Remaining time : 228.30915451049805
#
# Time for a single iteration : 0.44618892669677734
# Remaining time : 178.47557067871094
#
# Time for a single iteration : 0.3927037715911865
# Remaining time : 117.81113147735596
#
# Time for a single iteration : 0.36557555198669434
# Remaining time : 73.11511039733887
#
# Time for a single iteration : 0.3586771488189697
# Remaining time : 35.86771488189697
#
# Time for a single iteration : 0.41379451751708984
# Remaining time : 0.0
#
# Time for a single iteration : 6.331969976425171
# Remaining time : 5698.772978782654
#
# Time for a single iteration : 6.3699774742126465
# Remaining time : 5095.981979370117
#
# Time for a single iteration : 5.287646055221558
# Remaining time : 3701.3522386550903
#
# Time for a single iteration : 5.490973949432373
# Remaining time : 3294.584369659424
#
# Time for a single iteration : 2.338961362838745
# Remaining time : 1169.4806814193726
#
# Time for a single iteration : 2.8664987087249756
# Remaining time : 1146.5994834899902
#
# Time for a single iteration : 3.2675578594207764
# Remaining time : 980.2673578262329
#
# Time for a single iteration : 5.129151344299316
# Remaining time : 1025.8302688598633
#
# Time for a single iteration : 5.538219690322876
# ...
# Remaining time : 12.856721878051758
#
# Time for a single iteration : 0.020950794219970703
# Remaining time : 10.475397109985352
#
# Time for a single iteration : 0.024284839630126953
# Remaining time : 9.713935852050781
#
# Time for a single iteration : 0.020360231399536133
# Remaining time : 6.10806941986084
#
# Time for a single iteration : 0.019322872161865234
# Remaining time : 3.864574432373047
#
# Time for a single iteration : 0.020097732543945312
# Remaining time : 2.0097732543945312
#
# Time for a single iteration : 0.020992040634155273
# Remaining time : 0.0
#
# Time for a single iteration : 0.021300792694091797
# Remaining time : 19.170713424682617
#
# Time for a single iteration : 0.02127814292907715
# Remaining time : 17.02251434326172
#
# Time for a single iteration : 0.020360469818115234
# Remaining time : 14.252328872680664
#
# Time for a single iteration : 0.019977807998657227
# Remaining time : 11.986684799194336
#
# Time for a single iteration : 0.022166967391967773
# Remaining time : 11.083483695983887
#
# Time for a single iteration : 0.02079296112060547
# Remaining time : 8.317184448242188
#
# Time for a single iteration : 0.020319700241088867
# Remaining time : 6.09591007232666
#
# Time for a single iteration : 0.01926279067993164
# Remaining time : 3.852558135986328
#
# Time for a single iteration : 0.02034926414489746
# Remaining time : 2.034926414489746
#
# Time for a single iteration : 0.021548986434936523
# Remaining time : 0.0
#
# Time for a single iteration : 0.021016836166381836
# Remaining time : 18.915152549743652
#
# Time for a single iteration : 0.021088838577270508
# Remaining time : 16.871070861816406
#
# Time for a single iteration : 0.020032167434692383
# Remaining time : 14.022517204284668
#
# Time for a single iteration : 0.019541025161743164
# Remaining time : 11.724615097045898
#
# Time for a single iteration : 0.0189974308013916
# Remaining time : 9.4987154006958
#
# Time for a single iteration : 0.0205690860748291
# Remaining time : 8.22763442993164
#
# Time for a single iteration : 0.0200042724609375
# Remaining time : 6.00128173828125
#
# Time for a single iteration : 0.02589106559753418
# Remaining time : 5.178213119506836
#
# Time for a single iteration : 0.020739316940307617
# Remaining time : 2.0739316940307617
#
# Time for a single iteration : 0.020150423049926758
# Remaining time : 0.0
#
# Time for a single iteration : 0.01999950408935547
# Remaining time : 17.999553680419922
#
# Time for a single iteration : 0.020732641220092773
# Remaining time : 16.58611297607422
#
# Time for a single iteration : 0.020242929458618164
# Remaining time : 14.170050621032715
#
# Time for a single iteration : 0.01985311508178711
# Remaining time : 11.911869049072266
#
# Time for a single iteration : 0.018153667449951172
# Remaining time : 9.076833724975586
#
# Time for a single iteration : 0.02031421661376953
# Remaining time : 8.125686645507812
#
# Time for a single iteration : 0.02064228057861328
# Remaining time : 6.192684173583984
#
# Time for a single iteration : 0.02120804786682129
# Remaining time : 4.241609573364258
#
# Time for a single iteration : 0.019505739212036133
# Remaining time : 1.9505739212036133
#
# Time for a single iteration : 0.021779537200927734
# Remaining time : 0.0
#
# Time for a single iteration : 0.01950240135192871
# Remaining time : 17.55216121673584
#
# Time for a single iteration : 0.01952385902404785
# Remaining time : 15.619087219238281
#
# Time for a single iteration : 0.01756143569946289
# Remaining time : 12.293004989624023
#
# Time for a single iteration : 0.019824981689453125
# Remaining time : 11.894989013671875
#
# Time for a single iteration : 0.01739645004272461
# Remaining time : 8.698225021362305
#
# Time for a single iteration : 0.019511938095092773
# Remaining time : 7.804775238037109
#
# Time for a single iteration : 0.019517183303833008
# Remaining time : 5.855154991149902
#
# Time for a single iteration : 0.019442081451416016
# Remaining time : 3.888416290283203
#
# Time for a single iteration : 0.01956772804260254
# Remaining time : 1.956772804260254
#
# Time for a single iteration : 0.020624637603759766
# Remaining time : 0.0
#
# Time for a single iteration : 0.01900649070739746
# Remaining time : 17.105841636657715
#
# Time for a single iteration : 0.019268512725830078
# Remaining time : 15.414810180664062
#
# Time for a single iteration : 0.01633143424987793
# Remaining time : 11.43200397491455
#
# Time for a single iteration : 0.018962860107421875
# Remaining time : 11.377716064453125
#
# Time for a single iteration : 0.019040822982788086
# Remaining time : 9.520411491394043
#
# Time for a single iteration : 0.018205642700195312
# Remaining time : 7.282257080078125
#
# Time for a single iteration : 0.01903676986694336
# Remaining time : 5.711030960083008
#
# Time for a single iteration : 0.017349720001220703
# Remaining time : 3.4699440002441406
#
# Time for a single iteration : 0.018982410430908203
# Remaining time : 1.8982410430908203
#
# Time for a single iteration : 0.018917560577392578
# Remaining time : 0.0
# 8 1000
#
# Time for a single iteration : 0.03454089164733887
# Remaining time : 31.08680248260498
#
# Time for a single iteration : 0.03524446487426758
# Remaining time : 28.195571899414062
#
# Time for a single iteration : 0.03589463233947754
# Remaining time : 25.126242637634277
#
# Time for a single iteration : 0.047033071517944336
# Remaining time : 28.2198429107666
#
# Time for a single iteration : 0.04112052917480469
# Remaining time : 20.560264587402344
#
# Time for a single iteration : 0.04304337501525879
# Remaining time : 17.217350006103516
#
# Time for a single iteration : 0.04314589500427246
# Remaining time : 12.943768501281738
#
# Time for a single iteration : 0.03432869911193848
# Remaining time : 6.865739822387695
#
# Time for a single iteration : 0.033974409103393555
# Remaining time : 3.3974409103393555
#
# Time for a single iteration : 0.034503936767578125
# Remaining time : 0.0
#
# Time for a single iteration : 0.03442883491516113
# Remaining time : 30.98595142364502
#
# Time for a single iteration : 0.03393745422363281
# Remaining time : 27.14996337890625
#
# Time for a single iteration : 0.03420877456665039
# Remaining time : 23.946142196655273
#
# Time for a single iteration : 0.04384613037109375
# Remaining time : 26.30767822265625
#
# Time for a single iteration : 0.034216880798339844
# Remaining time : 17.108440399169922
#
# Time for a single iteration : 0.03396344184875488
# Remaining time : 13.585376739501953
#
# Time for a single iteration : 0.034269094467163086
# Remaining time : 10.280728340148926
#
# Time for a single iteration : 0.03434038162231445
# Remaining time : 6.868076324462891
#
# Time for a single iteration : 0.03409433364868164
# Remaining time : 3.409433364868164
#
# Time for a single iteration : 0.03396129608154297
# Remaining time : 0.0
#
# Time for a single iteration : 0.034539222717285156
# Remaining time : 31.08530044555664
#
# Time for a single iteration : 0.03424978256225586
# Remaining time : 27.399826049804688
#
# Time for a single iteration : 0.03410148620605469
# Remaining time : 23.87104034423828
#
# Time for a single iteration : 0.03428053855895996
# Remaining time : 20.568323135375977
#
# Time for a single iteration : 0.03480219841003418
# Remaining time : 17.40109920501709
#
# Time for a single iteration : 0.034560203552246094
# Remaining time : 13.824081420898438
#
# Time for a single iteration : 0.035073041915893555
# Remaining time : 10.521912574768066
#
# Time for a single iteration : 0.03823709487915039
# Remaining time : 7.647418975830078
#
# Time for a single iteration : 0.04140424728393555
# Remaining time : 4.140424728393555
#
# Time for a single iteration : 0.034150123596191406
# Remaining time : 0.0
#
# Time for a single iteration : 0.03442215919494629
# Remaining time : 30.97994327545166
#
# Time for a single iteration : 0.03378939628601074
# Remaining time : 27.031517028808594
#
# Time for a single iteration : 0.03513526916503906
# Remaining time : 24.594688415527344
#
# Time for a single iteration : 0.03466153144836426
# Remaining time : 20.796918869018555
#
# Time for a single iteration : 0.03598332405090332
# Remaining time : 17.99166202545166
#
# Time for a single iteration : 0.03381657600402832
# Remaining time : 13.526630401611328
#
# Time for a single iteration : 0.03503584861755371
# Remaining time : 10.510754585266113
#
# Time for a single iteration : 0.04575753211975098
# Remaining time : 9.151506423950195
#
# Time for a single iteration : 0.035102128982543945
# Remaining time : 3.5102128982543945
#
# Time for a single iteration : 0.03521323204040527
# Remaining time : 0.0
#
# Time for a single iteration : 0.03344988822937012
# Remaining time : 30.104899406433105
#
# Time for a single iteration : 0.033506155014038086
# Remaining time : 26.80492401123047
#
# Time for a single iteration : 0.03550219535827637
# Remaining time : 24.851536750793457
#
# Time for a single iteration : 0.03383350372314453
# Remaining time : 20.30010223388672
#
# Time for a single iteration : 0.03348898887634277
# Remaining time : 16.744494438171387
#
# Time for a single iteration : 0.039008140563964844
# Remaining time : 15.603256225585938
#
# Time for a single iteration : 0.038622140884399414
# Remaining time : 11.586642265319824
#
# Time for a single iteration : 0.03330516815185547
# Remaining time : 6.661033630371094
#
# Time for a single iteration : 0.033776044845581055
# Remaining time : 3.3776044845581055
#
# Time for a single iteration : 0.03335142135620117
# Remaining time : 0.0
#
# Time for a single iteration : 0.03295445442199707
# Remaining time : 29.659008979797363
#
# Time for a single iteration : 0.03273296356201172
# Remaining time : 26.186370849609375
#
# Time for a single iteration : 0.04073643684387207
# Remaining time : 28.51550579071045
#
# Time for a single iteration : 0.033599138259887695
# Remaining time : 20.159482955932617
#
# Time for a single iteration : 0.040576934814453125
# Remaining time : 20.288467407226562
#
# Time for a single iteration : 0.03536367416381836
# Remaining time : 14.145469665527344
#
# Time for a single iteration : 0.03303956985473633
# Remaining time : 9.911870956420898
#
# Time for a single iteration : 0.032860755920410156
# Remaining time : 6.572151184082031
#
# Time for a single iteration : 0.033461809158325195
# Remaining time : 3.3461809158325195
#
# Time for a single iteration : 0.03275871276855469
# Remaining time : 0.0
# 8 2500
#
# Time for a single iteration : 0.15157294273376465
# Remaining time : 136.41564846038818
#
# Time for a single iteration : 0.17160654067993164
# Remaining time : 137.2852325439453
#
# Time for a single iteration : 0.16721224784851074
# Remaining time : 117.04857349395752
#
# Time for a single iteration : 0.13267230987548828
# Remaining time : 79.60338592529297
#
# Time for a single iteration : 0.16629862785339355
# Remaining time : 83.14931392669678
#
# Time for a single iteration : 0.16746997833251953
# Remaining time : 66.98799133300781
#
# Time for a single iteration : 0.19714140892028809
# Remaining time : 59.142422676086426
#
# Time for a single iteration : 0.1845700740814209
# Remaining time : 36.91401481628418
#
# Time for a single iteration : 0.21655011177062988
# Remaining time : 21.65501117706299
#
# Time for a single iteration : 0.22037672996520996
# Remaining time : 0.0
#
# Time for a single iteration : 0.1933276653289795
# Remaining time : 173.99489879608154
#
# Time for a single iteration : 0.17165660858154297
# Remaining time : 137.32528686523438
#
# Time for a single iteration : 0.16828203201293945
# Remaining time : 117.79742240905762
#
# Time for a single iteration : 0.17454957962036133
# Remaining time : 104.7297477722168
#
# Time for a single iteration : 0.17593741416931152
# Remaining time : 87.96870708465576
#
# Time for a single iteration : 0.2044532299041748
# Remaining time : 81.78129196166992
#
# Time for a single iteration : 0.1793828010559082
# Remaining time : 53.81484031677246
#
# Time for a single iteration : 0.16195058822631836
# Remaining time : 32.39011764526367
#
# Time for a single iteration : 0.20522165298461914
# Remaining time : 20.522165298461914
#
# Time for a single iteration : 0.20109272003173828
# Remaining time : 0.0
#
# Time for a single iteration : 0.20432615280151367
# Remaining time : 183.8935375213623
#
# Time for a single iteration : 0.17834782600402832
# Remaining time : 142.67826080322266
#
# Time for a single iteration : 0.20087885856628418
# Remaining time : 140.61520099639893
#
# Time for a single iteration : 0.20939278602600098
# Remaining time : 125.63567161560059
#
# Time for a single iteration : 0.16562461853027344
# Remaining time : 82.81230926513672
#
# Time for a single iteration : 0.21379780769348145
# Remaining time : 85.51912307739258
#
# Time for a single iteration : 0.21789789199829102
# Remaining time : 65.3693675994873
#
# Time for a single iteration : 0.1512763500213623
# Remaining time : 30.25527000427246
#
# Time for a single iteration : 0.21111774444580078
# Remaining time : 21.111774444580078
#
# Time for a single iteration : 0.17816996574401855
# Remaining time : 0.0
#
# Time for a single iteration : 0.18470287322998047
# Remaining time : 166.23258590698242
#
# Time for a single iteration : 0.21147775650024414
# Remaining time : 169.1822052001953
#
# Time for a single iteration : 0.20406079292297363
# Remaining time : 142.84255504608154
#
# Time for a single iteration : 0.18385004997253418
# Remaining time : 110.31002998352051
#
# Time for a single iteration : 0.2026066780090332
# Remaining time : 101.3033390045166
#
# Time for a single iteration : 0.21240997314453125
# Remaining time : 84.9639892578125
#
# Time for a single iteration : 0.21114850044250488
# Remaining time : 63.344550132751465
#
# Time for a single iteration : 0.21692967414855957
# Remaining time : 43.385934829711914
#
# Time for a single iteration : 0.1893298625946045
# Remaining time : 18.93298625946045
#
# Time for a single iteration : 0.2038867473602295
# Remaining time : 0.0
#
# Time for a single iteration : 0.12704205513000488
# Remaining time : 114.3378496170044
#
# Time for a single iteration : 0.20256400108337402
# Remaining time : 162.05120086669922
#
# Time for a single iteration : 0.2017803192138672
# Remaining time : 141.24622344970703
#
# Time for a single iteration : 0.18595075607299805
# Remaining time : 111.57045364379883
#
# Time for a single iteration : 0.17406535148620605
# Remaining time : 87.03267574310303
#
# Time for a single iteration : 0.14187073707580566
# Remaining time : 56.748294830322266
#
# Time for a single iteration : 0.21767592430114746
# Remaining time : 65.30277729034424
#
# Time for a single iteration : 0.12833714485168457
# Remaining time : 25.667428970336914
#
# Time for a single iteration : 0.20291948318481445
# Remaining time : 20.291948318481445
#
# Time for a single iteration : 0.20698142051696777
# Remaining time : 0.0
#
# Time for a single iteration : 0.11990022659301758
# Remaining time : 107.91020393371582
#
# Time for a single iteration : 0.17363333702087402
# Remaining time : 138.90666961669922
#
# Time for a single iteration : 0.1598961353302002
# Remaining time : 111.92729473114014
#
# Time for a single iteration : 0.1540236473083496
# Remaining time : 92.41418838500977
#
# Time for a single iteration : 0.17810416221618652
# Remaining time : 89.05208110809326
#
# Time for a single iteration : 0.15345382690429688
# Remaining time : 61.38153076171875
#
# Time for a single iteration : 0.11957645416259766
# Remaining time : 35.8729362487793
#
# Time for a single iteration : 0.11939644813537598
# Remaining time : 23.879289627075195
#
# Time for a single iteration : 0.20520329475402832
# Remaining time : 20.520329475402832
#
# Time for a single iteration : 0.16768527030944824
# Remaining time : 0.0
#
# Time for a single iteration : 2.274017095565796
# Remaining time : 2046.6153860092163
#
# Time for a single iteration : 3.0013227462768555
# Remaining time : 2401.0581970214844
#
# Time for a single iteration : 3.238584280014038
# Remaining time : 2267.0089960098267
#
# Time for a single iteration : 2.4839119911193848
# Remaining time : 1490.3471946716309
#
# Time for a single iteration : 3.1012871265411377
# Remaining time : 1550.6435632705688
#
# Time for a single iteration : 2.3099889755249023
# Remaining time : 923.9955902099609
#
# Time for a single iteration : 2.288843870162964
# Remaining time : 686.6531610488892
#
# Time for a single iteration : 2.282853364944458
# Remaining time : 456.5706729888916
#
# Time for a single iteration : 2.2748162746429443
# Remaining time : 227.48162746429443

# %%
## ns = 10

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([12,15,25,50,100,250,500,1000,2500])
n_s = 10 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.05
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 25
BS = totalSize
nmax = 1000

critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []

for nmc in range(N_MC):

    X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=2,alpha=rho)
    
    t2 = time.time()
    out,FMw,th = dgo.Core_DGMCA(X=X,n=5,A=Ainit,kend=kend,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=totalSize, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
    t3 = time.time()
    Time.append(t3-t2)
    critA.append(EvalCriterion_eval(A0,S0,out,S0)['ca_mean'])
    
    print(nmc,BS)
    
    for r in range(len(vBS)):

        BS = vBS[r]
        
        print(nmc,BS)
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUCeq.append(t2-t1)
        critA_EUCeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUC.append(t2-t1)
        critA_EUC.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        sio.savemat("DGMCA_Nobs20_ns10_Cd2_May20.mat",mdict={"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})

# %%
import scipy.io as sio

critA_omp = []
critA = []
Time_omp = []
Time = []

totalSize = 10000
vBS = np.array([17,25,50,100,250,500,1000,2500])
n_s = 15 # Number of sources
n_obs = 20 # Number of observations        
rho = 0.05
Ainit = np.random.randn(n_obs,n_s)
Ainit = Ainit/np.maximum(0,np.linalg.norm(Ainit,axis=0))
kend = 1

N_MC = 25
BS = totalSize
nmax = 1000

critA_FMeq = []
Time_FMeq = []
critA_FM = []
Time_FM = []
critA_rFMeq = []
Time_rFMeq = []
critA_rFM = []
Time_rFM = []
critA_EUCeq = []
Time_EUCeq = []
critA_EUC = []
Time_EUC = []

for nmc in range(N_MC):

    X,X0,A0,S0,N = Make_Experiment_GG(n_s=n_s,n_obs=n_obs,t_samp=totalSize,noise_level=40.0,dynamic=1,CondNumber=2,alpha=rho)
    
    t2 = time.time()
    out,FMw,th = dgo.Core_DGMCA(X=X,n=5,A=Ainit,kend=kend,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=totalSize, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
    t3 = time.time()
    Time.append(t3-t2)
    critA.append(EvalCriterion_eval(A0,S0,out,S0)['ca_mean'])
    
    print(nmc,BS)
    
    for r in range(len(vBS)):

        BS = vBS[r]
        
        print(nmc,BS)
        
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FMeq.append(t2-t1)
        critA_FMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='FM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_FM.append(t2-t1)
        critA_FM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFMeq.append(t2-t1)
        critA_rFMeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='rFM',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_rFM.append(t2-t1)
        critA_rFM.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=True,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUCeq.append(t2-t1)
        critA_EUCeq.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        t1 = time.time()
        out_omp,FMw,th = dgo.Core_DGMCA(X=X,n=n_s,A=Ainit,kend=kend,AggMeth='Euclidean',Equal=False,q_f=0.1,nmax=nmax,L0=1,verb=0,Kmax=0.5,tol=1e-6, subBlockSize=BS, SCOpt=1,alphaEstOpt=1,alpha_exp=2.)
        t2 = time.time()
        Time_EUC.append(t2-t1)
        critA_EUC.append(EvalCriterion_eval(A0,S0,out_omp,S0)['ca_mean'])
        
        sio.savemat("DGMCA_Nobs20_ns15_Cd2_May20.mat",mdict={"Time":Time,"critA":critA,"Time_FMeq":Time_FMeq,"critA_FMeq":critA_FMeq,"Time_FM":Time_FM,"critA_FM":critA_FM,"Time_rFMeq":Time_rFMeq,"critA_rFMeq":critA_rFMeq,"Time_rFM":Time_rFM,"critA_rFM":critA_rFM,"Time_EUCeq":Time_EUCeq,"critA_EUCeq":critA_EUCeq,"Time_EUC":Time_EUC,"critA_EUC":critA_EUC})
